# %% [markdown]
# # Processing GitHub Events Taken From BigQuery
#
# After making an account with BigQuery the following SQL commands were used to extract the events from 2016 - May 19, 2017 for all 99 repos and their forks taken from SamplingProcess.ipynb. This was ran on May 20, 2017 at 5:02 PM PST.
#
# `SELECT type,
#        payload,
#        repo.id AS repo_id,
#        actor.id AS user_id,
#        actor.login AS login,
#        created_at,
#        id AS archive_id
#   FROM [githubarchive]
#  WHERE repo.id IN (
#            SELECT repo_id
#              FROM [repos_table]
#        );`
#
# The files were exported and are called 2016_events.gz, 2017_01_events.gz, 2017_02_events.gz, 2017_03_events.gz, 2017_04_events.gz, 2017_05_events.gz. Instead of reading all these files in they were combined with the following shell command.
#
# `cat *.gz > events.gz`
#
# These files can be downloaded from the link on the README.

# %%
import pandas as pd
import sqlite3 as sql
import json
import sys
stdout = sys.stdout
reload(sys)
sys.setdefaultencoding('utf8')
sys.stdout = stdout

con = sql.connect('github.db')
c = con.cursor()

# %% [markdown]
# ## Reading in the combined file
#
# NOTE: Since all files were combined, there are rows that have the same header names that need to be removed

# %%
events = pd.read_table('events.gz', sep=',', engine='c')

# %%
# find the indices of headers
rm_indices = events['type'][events['type']== 'type'].index

# drop the indicies
events = events.drop(events.index[[rm_indices]])

# %%
# fix encoding in payload
events['payload'] = events['payload'].str.encode('ascii', 'ignore')

# change str representation of dict to actual dict
events['payload'] = events['payload'].apply(json.loads)

# change data type to numeric
events[['repo_id', 'user_id', 'archive_id']] = events[['repo_id', 'user_id', 'archive_id']].applymap(pd.to_numeric)

# change data type to date
events['created_at'] = events['created_at'].apply(pd.to_datetime)

events.shape
# Out:
# (478495, 7)

# %%
# reselect all the repos (accidentally chose repos with issuses not in english)
repos_ids = pd.read_sql('SELECT DISTINCT(repo_id) AS repos_ids FROM repos;', con)

# %%
events = events[events.repo_id.isin(repos_ids.repos_ids)]

events.shape
# Out:
# (475273, 7)

# %%
events['type'].unique()
# Out:
# array(['ForkEvent', 'PushEvent', 'WatchEvent', 'CreateEvent',
#        'DeleteEvent', 'GollumEvent', 'IssuesEvent', 'PullRequestEvent',
#        'IssueCommentEvent', 'CommitCommentEvent',
#        'PullRequestReviewCommentEvent', 'ReleaseEvent', 'MemberEvent',
#        'PublicEvent'], dtype=object)

# %% [markdown]
# ## Creating a user table
#
# Run once... Now that all the events are available we can we create a table of unique users and then drop the login and archive_id

# %%
create_users_table = '''
CREATE TABLE users (
    user_id NUMERIC      NOT NULL,
    login   VARCHAR (40) NOT NULL,
    PRIMARY KEY (
        user_id,
        login
    )
)
WITHOUT ROWID;'''

# %%
c.execute(create_users_table)
con.commit()

# %%
# users can can change their login name so there are duplicate user_id's 
# or login name can be from the user referenced as an organization they're part of
user_table = events[['user_id', 'login']].drop_duplicates()

user_table.to_sql(name='users', con=con, if_exists='append', index=False)

# %% [markdown]
# # Event Payloads To Tables In The Database

# %% [markdown]
# ## Watch Event
# The WatchEvent is related to starring a repository, not watching. See this API blog post for an explanation. The event’s actor is the user who starred a repository, and the event’s repository is the repository that was starred.
#
# `
# KEY     TYPE    DESCRIPTION
# action  string  The action that was performed. Currently, can only be started.`

# %%
# check the structure of Watch Event
events[events['type'] == 'WatchEvent'].head()
# Out:
#           type                  payload   repo_id  user_id           login  \
# 21  WatchEvent  {u'action': u'started'}  55584626    33275         waigani
# 22  WatchEvent  {u'action': u'started'}  72145556  8845083           v7lin
# 23  WatchEvent  {u'action': u'started'}  64392484  1678118         bbbenji
# 24  WatchEvent  {u'action': u'started'}  69798748   128654         BekoBou
# 25  WatchEvent  {u'action': u'started'}  69798748  1716049  antonvasilenko
#
#             created_at  archive_id
# 21 2016-05-20 09:37:31  4040270085
# 22 2016-12-14 01:57:21  5017278521
# 23 2016-08-07 19:17:47  4383818313
# 24 2016-10-19 15:40:14  4735036669
# 25 2016-10-28 14:37:24  4782874020

# %%
watch_table = events[['repo_id', 'user_id', 'login', 'created_at', 'archive_id']][events['type'] == 'WatchEvent']

# %%
# rename cols and change data type
watch_table = watch_table.rename(columns={'created_at':'date_starred', 'login':'user_login'})

watch_table['date_starred'] = watch_table['date_starred'].apply(pd.to_datetime)

# %%
print watch_table.shape

watch_table.head()
# Out:
# (230336, 5)
#      repo_id  user_id      user_login        date_starred  archive_id
# 21  55584626    33275         waigani 2016-05-20 09:37:31  4040270085
# 22  72145556  8845083           v7lin 2016-12-14 01:57:21  5017278521
# 23  64392484  1678118         bbbenji 2016-08-07 19:17:47  4383818313
# 24  69798748   128654         BekoBou 2016-10-19 15:40:14  4735036669
# 25  69798748  1716049  antonvasilenko 2016-10-28 14:37:24  4782874020

# %%
# drop all duplicates across ALL columns
watch_table = watch_table.drop_duplicates()

print watch_table.shape
# Out:
# (230198, 5)

# %%
create_watch_table = '''
CREATE TABLE watch_events (
    repo_id      NUMERIC      NOT NULL,
    date_starred TEXT         NOT NULL,
    user_id      NUMERIC      NOT NULL,
    user_login   VARCHAR (40) NOT NULL,
    archive_id   NUMERIC      NOT NULL,
    PRIMARY KEY (
        repo_id,
        user_id,
        date_starred,
        archive_id
    )
)
WITHOUT ROWID;
'''

# %%
c.execute(create_watch_table)
con.commit()

# %%
watch_table.to_sql(name='watch_events', con=con, if_exists='append', index=False)

# %% [markdown]
# ## Push Event
# Triggered when a repository branch is pushed to. In addition to branch pushes, webhook push events are also triggered when repository tags are pushed.
#
# `
# KEY                       TYPE      DESCRIPTION
# ref                       string    The full Git ref that was pushed. Example: "refs/heads/master".
# head	                  string    The SHA of the most recent commit on ref after the push.
# before                    string    The SHA of the most recent commit on ref before the push.
# size	                  integer   The number of commits in the push.
# distinct_size             integer   The number of distinct commits in the push.
# commits                   array     An array of commit objects describing the pushed commits. (The array includes a
#                                     maximum of 20 commits. If necessary, you can use the Commits API to fetch
#                                     additional commits. This limit is applied to timeline events only and isn't
#                                     applied to webhook deliveries.)
# commits[][sha]            string	The SHA of the commit.
# commits[][message]        string	The commit message.
# commits[][author]         object	The git author of the commit.
# commits[][author][name]   string	The git author's name.
# commits[][author][email]  string	The git author's email address.
# commits[][url]            url       Points to the commit API resource.
# commits[][distinct]       boolean   Whether this commit is distinct from any that have been pushed before.
# `

# %%
events[events['type'] == 'PushEvent'].head()
# Out:
#          type                                            payload   repo_id  \
# 7   PushEvent  {u'size': 1, u'head': u'9ace8b54e6b6199109e4f8...  58482213
# 8   PushEvent  {u'size': 2, u'head': u'1bb34dc6a8c738c65474e9...  67361765
# 9   PushEvent  {u'size': 1, u'head': u'dafa402c9b56f6ca7e388c...  63506379
# 10  PushEvent  {u'size': 3, u'head': u'7aba5f0eb216b3127b7522...  65438297
# 11  PushEvent  {u'size': 1, u'head': u'5ba0cd4c4706426a6fce75...  75232752
#
#     user_id        login               created_at  archive_id
# 7   2467194  yoshuawuyts  2016-08-29 02:28:48 UTC  4481961993
# 8   2182307        jpuri  2016-10-24 19:14:12 UTC  4758352997
# 9   4643257    AeonLucid  2016-08-07 12:37:43 UTC  4383281798
# 10  3266682     dgcrouse  2016-08-23 06:02:58 UTC  4455249468
# 11  2057020        neskk  2016-12-02 09:08:54 UTC  4958264505

# %%
# check the structure of a push event
events['payload'][events['type'] == 'PushEvent'].iloc[0]
# Out:
# {u'before': u'1bba545d19231f5d1030f742673db07db98e354f',
#  u'commits': [{u'author': {u'email': u'a1a7f265cb3ad36479782781c7488a7b334751fd@gmail.com',
#     u'name': u'Yoshua Wuyts'},
#    u'distinct': True,
#    u'message': u'tests: fix history',
#    u'sha': u'9ace8b54e6b6199109e4f867d5404e94dc6f2efd',
#    u'url': u'https://api.github.com/repos/yoshuawuyts/choo/commits/9ace8b54e6b6199109e4f867d5404e94dc6f2efd'}],
#  u'distinct_size': 1,
#  u'head': u'9ace8b54e6b6199109e4f867d5404e94dc6f2efd',
#  u'push_id': 1271365738,
#  u'ref': u'refs/heads/update-router',
#  u'size': 1}

# %%
# checking the different sizes of commits
PushEvent_payload['distinct_size'].unique()
# Out:
# array([   1,    2,    3,    4,    5,   11,    0,   89,   73,    6,   37,
#          16,    7,   15,   53,   18,   19,    9,   13,    8,   25,   12,
#         183,   10,   14,   24,   22,   27,   43,   75,   76,  141,   30,
#          55,   85,   32,   90,   29,   21,   28,   40,   44,   35,   66,
#         108,   34,   38,  420,   67,   20,   23,  261,   58,   17,  238,
#          98,   99,   31,  342,  833,   26,  178,   63,  135,  179,   68,
#          95,   48,   80,   62,   42,  112,   41,   54,   36,  171,   64,
#          46,  130,  532,   70,   91,   56,  474,   69,  136,  262,   71,
#         169,   97,   84,  114,  321,   33,  175,  426,  268,  218,   94,
#         148,  499,   74,   57,   39,  351,  122,  251,  213,   51,   72,
#         128,  216,  111,   93,   50,  120,   45,  106,  713,   81,  392,
#          49,   88,  147,  314,  187,   86,  115,  126,   79,   60,  233,
#         297,  104,  185,  157,   59,  127,   65,  294,   92,  140,  264,
#         105,  158,   52,  331,  121,  493,  172,   82,  414,  155,   47,
#         102, 1199,  177,  253,  192,  945,  123,  328,   96,  197,  344,
#         490,  633,  107,  152,  202,  304,  118,  203,  200,  405,  151,
#         137,  165,  247,   77,  212,  286,  424, 1124,   83,  193,  201,
#         249,  305,  278,  497,  788,  116,  132,  272,  332, 1219,  226,
#         599,  486,  429,  225,  150,  153,  173,  125,  413,  244,  194,
#         423,  324,  463,  591, 1480, 1447, 1562,  138, 1477,   87,  279,
#         117,  221,  774, 1487,  228,  796,  195, 1144,  243,   78,  156,
#         260,  362])

# %% [markdown]
# ## Issue Comment Event
# Triggered when an issue comment is created, edited, or deleted.
#
# `
# KEY                 TYPE    DESCRIPTION
# action              string  The action that was performed on the comment. Can be one of "created", "edited", or
#                             "deleted".
# changes             object  The changes to the comment if the action was "edited".
# changes[body][from] string  The previous version of the body if the action was "edited".
# issue               object  The issue the comment belongs to.
# comment             object  The comment itself.
# `

# %%
IssueCommentEvents = events[events['type'] == 'IssueCommentEvent']

# %%
# example of a payload
IssueCommentEvents['payload'].iloc[0]
# Out:
# {u'action': u'created',
#  u'comment': {u'body': u'Ya once formatted you will have to transfer again',
#   u'created_at': u'2016-10-29T14:22:29Z',
#   u'html_url': u'https://github.com/Plailect/Guide/issues/665#issuecomment-257094294',
#   u'id': 257094294,
#   u'issue_url': u'https://api.github.com/repos/Plailect/Guide/issues/665',
#   u'updated_at': u'2016-10-29T14:22:29Z',
#   u'url': u'https://api.github.com/repos/Plailect/Guide/issues/comments/257094294',
#   u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/17306233?v=3',
#    u'events_url': u'https://api.github.com/users/pbanj/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/pbanj/followers',
#    u'following_url': u'https://api.github.com/users/pbanj/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/pbanj/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/pbanj',
#    u'id': 17306233,
#    u'login': u'pbanj',
#    u'organizations_url': u'https://api.github.com/users/pbanj/orgs',
#    u'received_events_url': u'https://api.github.com/users/pbanj/received_events',
#    u'repos_url': u'https://api.github.com/users/pbanj/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/pbanj/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/pbanj/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/pbanj'}},
#  u'issue': {u'assignee': None,
#   u'assignees': [],
#   u'body': u'I did the system transfer and was able to redownload Fieldrunners onto 3DS 2, but when going the troubleshooting section, copying the still working save from 3DS 1\'s system to microSD and using that card on 3DS 2, on the microSD section of DSiware management, it says "There is no accessible data." What are my options?',
#   u'closed_at': None,
#   u'comments': 4,
#   u'comments_url': u'https://api.github.com/repos/Plailect/Guide/issues/665/comments',
#   u'created_at': u'2016-10-29T06:26:26Z',
#   u'events_url': u'https://api.github.com/repos/Plailect/Guide/issues/665/events',
#   u'html_url': u'https://github.com/Plailect/Guide/issues/665',
#   u'id': 186062739,
#   u'labels': [],
#   u'labels_url': u'https://api.github.com/repos/Plailect/Guide/issues/665/labels{/name}',
#   u'locked': False,
#   u'milestone': None,
#   u'number': 665,
#   u'repository_url': u'https://api.github.com/repos/Plailect/Guide',
#   u'state': u'open',
#   u'title': u'Troubleshooting lost DSIware save hits a dead end.',
#   u'updated_at': u'2016-10-29T14:22:29Z',
#   u'url': u'https://api.github.com/repos/Plailect/Guide/issues/665',
#   u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/10488946?v=3',
#    u'events_url': u'https://api.github.com/users/ForcedToRock/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/ForcedToRock/followers',
#    u'following_url': u'https://api.github.com/users/ForcedToRock/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/ForcedToRock/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/ForcedToRock',
#    u'id': 10488946,
#    u'login': u'ForcedToRock',
#    u'organizations_url': u'https://api.github.com/users/ForcedToRock/orgs',
#    u'received_events_url': u'https://api.github.com/users/ForcedToRock/received_events',
#    u'repos_url': u'https://api.github.com/users/ForcedToRock/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/ForcedToRock/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/ForcedToRock/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/ForcedToRock'}}}

# %%
ICL = []

for index, row in IssueCommentEvents.iterrows():
    
    payload = row['payload']
    comment = payload['comment']
    issue = payload['issue']
    
    ICL.append({'repo_id': row['repo_id'], 'user_id': row['user_id'], 
               'user_login': row['login'], 'date_created': row['created_at'],
               'archive_id': row['archive_id'], 'action': payload['action'], 
               'comment': comment['body'], 'issue_comment_id': pd.to_numeric(comment['id']), 
                'url': comment['html_url'], 'issue_id': pd.to_numeric(issue['id']),
               'issue_state': issue['state']})

# %%
# check the structure of issue comment Event
len(ICL)
# Out:
# 69821

# %%
issue_comments_table = pd.DataFrame(ICL)

# %%
issue_comments_table.head()
# Out:
#     action  archive_id                                            comment  \
# 0  created  4786583626  Ya once formatted you will have to transfer again
# 1  created  4404634353  it only seems to happen to be when I am on the...
# 2  created  3885837271  BTW - this I ran into this because of a [commo...
# 3  created  4400512395  Looks like this feature isn't avaible from the...
# 4  created  4073978702  +1 I was going to make a similar PR as well fo...
#
#          date_created  issue_comment_id   issue_id issue_state   repo_id  \
# 0 2016-10-29 14:22:29         257094294  186062739        open  52920387
# 1 2016-08-11 12:44:22         239150022  170343029        open  63730796
# 2 2016-04-13 21:48:02         209662472  148192004        open  54994103
# 3 2016-08-10 18:03:45         238951429  170368421      closed  64392484
# 4 2016-05-28 04:18:24         222289102  156508185        open  53321815
#
#                                                  url   user_id     user_login
# 0  https://github.com/Plailect/Guide/issues/665#i...  17306233          pbanj
# 1  https://github.com/mchristopher/PokemonGo-Desk...   5121698  justinblayney
# 2  https://github.com/FezVrasta/popper.js/issues/...    136564      rosskevin
# 3  https://github.com/kvangent/PokeAlarm/issues/7...  10712294       kvangent
# 4  https://github.com/picturepan2/spectre/pull/55...   5353151           DJTB

# %%
# only created events
issue_comments_table['action'].unique()
# Out:
# array([u'created'], dtype=object)

# %%
# drop any duplicates across ALL columns (not sure why they would be there though???)
issue_comments_table = issue_comments_table.drop_duplicates()

# %%
create_issue_comments_table = '''
CREATE TABLE issue_comment_events (
    issue_comment_id NUMERIC      NOT NULL,
    issue_id         NUMERIC      NOT NULL,
    repo_id          NUMERIC      NOT NULL,
    date_created     TEXT         NOT NULL,
    [action]         VARCAHR (15) NOT NULL,
    comment          TEXT,
    issue_state      VARCHAR (15) NOT NULL,
    url              TEXT         NOT NULL,
    user_id          NUMERIC      NOT NULL,
    user_login       VARCHAR (40) NOT NULL,
    archive_id       NUMERIC      NOT NULL,
    PRIMARY KEY (
        issue_comment_id,
        issue_id,
        repo_id,
        date_created
    )
)
WITHOUT ROWID;
'''

# %%
c.execute(create_issue_comments_table)
con.commit()

# %%
issue_comments_table.to_sql(name='issue_comment_events', con=con, if_exists='append', index=False)

# %% [markdown]
# ## Fork Event
# Triggered when a user forks a repository.
#
# `
# KEY     TYPE    DESCRIPTION
# forkee  object  The created repository.
# `

# %%
# check the structure of Watch Event
events['payload'][events['type'] == 'ForkEvent'].iloc[0]
# Out:
# {u'forkee': {u'archive_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/branches{/branch}',
#   u'clone_url': u'https://github.com/DavidKindler/js-stack-from-scratch.git',
#   u'collaborators_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/contributors',
#   u'created_at': u'2016-10-27T17:36:59Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/deployments',
#   u'description': u'Step-by-step tutorial to build a modern JavaScript stack from scratch',
#   u'downloads_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/downloads',
#   u'events_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/events',
#   u'fork': True,
#   u'forks': 0,
#   u'forks_count': 0,
#   u'forks_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/forks',
#   u'full_name': u'DavidKindler/js-stack-from-scratch',
#   u'git_commits_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/git/tags{/sha}',
#   u'git_url': u'git://github.com/DavidKindler/js-stack-from-scratch.git',
#   u'has_downloads': True,
#   u'has_issues': False,
#   u'has_pages': False,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/hooks',
#   u'html_url': u'https://github.com/DavidKindler/js-stack-from-scratch',
#   u'id': 72132487,
#   u'issue_comment_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/labels{/name}',
#   u'language': None,
#   u'languages_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/languages',
#   u'merges_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/merges',
#   u'milestones_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'js-stack-from-scratch',
#   u'notifications_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/notifications{?since,all,participating}',
#   u'open_issues': 0,
#   u'open_issues_count': 0,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1718785?v=3',
#    u'events_url': u'https://api.github.com/users/DavidKindler/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/DavidKindler/followers',
#    u'following_url': u'https://api.github.com/users/DavidKindler/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/DavidKindler/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/DavidKindler',
#    u'id': 1718785,
#    u'login': u'DavidKindler',
#    u'organizations_url': u'https://api.github.com/users/DavidKindler/orgs',
#    u'received_events_url': u'https://api.github.com/users/DavidKindler/received_events',
#    u'repos_url': u'https://api.github.com/users/DavidKindler/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/DavidKindler/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/DavidKindler/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/DavidKindler'},
#   u'private': False,
#   u'public': True,
#   u'pulls_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/pulls{/number}',
#   u'pushed_at': u'2016-10-27T17:34:32Z',
#   u'releases_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/releases{/id}',
#   u'size': 687,
#   u'ssh_url': u'git@github.com:DavidKindler/js-stack-from-scratch.git',
#   u'stargazers_count': 0,
#   u'stargazers_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/subscription',
#   u'svn_url': u'https://github.com/DavidKindler/js-stack-from-scratch',
#   u'tags_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/tags',
#   u'teams_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/teams',
#   u'trees_url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch/git/trees{/sha}',
#   u'updated_at': u'2016-10-27T17:36:57Z',
#   u'url': u'https://api.github.com/repos/DavidKindler/js-stack-from-scratch',
#   u'watchers': 0,
#   u'watchers_count': 0}}

# %% [markdown]
# ## Issues Event
# Triggered when an issue is assigned, unassigned, labeled, unlabeled, opened, edited, milestoned, demilestoned, closed, or reopened.
#
# `
# KEY                  TYPE    DESCRIPTION
# action               string  The action that was performed. Can be one of "assigned", "unassigned", "labeled",
#                              "unlabeled", "opened", "edited", "milestoned", "demilestoned", "closed", or "reopened".
# issue                object  The issue itself.
# changes              object  The changes to the issue if the action was "edited".
# changes[title][from] string  The previous version of the title if the action was "edited".
# changes[body][from]  string  The previous version of the body if the action was "edited".
# assignee             object  The optional user who was assigned or unassigned from the issue.
# label                object  The optional label that was added or removed from the issue.
# `

# %%
IssueEvents = events[events['type'] == 'IssuesEvent']

print IssueEvents.shape
# Out:
# (27585, 7)

# %%
IL = []

for index, row in IssueEvents.iterrows():
    
    payload = row['payload']
    issue = payload['issue']
    
    try:
        labels = []
        for labs in issue['labels']:            
            labels.append(labs['name'])
        labels = '::'.join(labels)
    except:
        labels = None

    IL.append({'repo_id': row['repo_id'], 'user_id': row['user_id'], 
               'user_login': row['login'], 'date_created': row['created_at'],
               'archive_id': row['archive_id'], 'action': payload['action'],
               'description': issue['body'], 'comments_count': pd.to_numeric(issue['comments']),
               'issue_id': pd.to_numeric(issue['id']), 'issue_number': pd.to_numeric(issue['number']),
               'title': issue['title'], 'labels': labels, 'url':issue['html_url']})

# %%
issue_table = pd.DataFrame(IL)

# %%
issue_table.head()
# Out:
#    action  archive_id  comments_count        date_created  \
# 0  closed  3900021338               2 2016-04-18 02:06:46
# 1  opened  4545891531               0 2016-09-11 14:18:12
# 2  opened  4676639609               0 2016-10-07 12:40:12
# 3  closed  4287637946               1 2016-07-16 22:07:29
# 4  closed  4841857831               1 2016-11-09 17:11:30
#
#                                          description   issue_id  issue_number  \
# 0  I noticed in the screenshot it looks different...  149019668             4
# 1  I am using Mac OSX and the tracker will work g...  176245961          1209
# 2  Hi,\r\n\r\nThank you very much for the plugin....  181658747           133
# 3  *(6/20: updated the numbers)*\r\n\r\nI don't c...  161111673             5
# 4  https://plailect.github.io/Guide/updating-a9lh...  188194735           695
#
#   labels   repo_id                                              title  \
# 0         53632140                                How to modify theme
# 1         63730796                     how to avoid getting IP banned
# 2         61213281  Expand and Contract Messages in the android no...
# 3         57929326     CSrankings is missing half my papers (on DBLP)
# 4         52920387  Add an optional label to section IV on updatin...
#
#                                                  url   user_id    user_login
# 0         https://github.com/zyedidia/micro/issues/4     24260  montanaflynn
# 1  https://github.com/mchristopher/PokemonGo-Desk...  22104808   lochnesskid
# 2  https://github.com/fechanique/cordova-plugin-f...  19806010        iamntg
# 3  https://github.com/emeryberger/CSrankings/issu...   1612723   emeryberger
# 4       https://github.com/Plailect/Guide/issues/695  16979510      Plailect

# %%
# drop any duplicates across ALL columns (not sure why they would be there though???)
issue_table = issue_table.drop_duplicates()

# %%
create_issues_table = '''
CREATE TABLE issues_events (
    issue_id       NUMERIC      NOT NULL,
    repo_id        NUMERIC      NOT NULL,
    date_created   TEXT         NOT NULL,
    [action]       VARCAHR (15) NOT NULL,
    title          TEXT,
    description    TEXT,
    labels         TEXT,
    issue_number   NUMERIC,
    comments_count INT,
    url            TEXT         NOT NULL,
    user_id        NUMERIC      NOT NULL,
    user_login     VARCHAR (40) NOT NULL,
    archive_id     NUMERIC      NOT NULL,
    PRIMARY KEY (
        issue_id,
        repo_id,
        date_created,
        [action]
    )
)
WITHOUT ROWID;
'''

# %%
c.execute(create_issues_table)
con.commit()

# %%
issue_table.to_sql(name='issues_events', con=con, if_exists='append', index=False)

# %% [markdown]
# ## Pull Request Event
# Triggered when a pull request is assigned, unassigned, labeled, unlabeled, opened, edited, closed, reopened, or synchronized. Also triggered when a pull request review is requested, or when a review request is removed.
#
# `
# KEY                  TYPE     DESCRIPTION
# action               string   The action that was performed. Can be one of "assigned", "unassigned",
#                               "review_requested", "review_request_removed", "labeled", "unlabeled", "opened",
#                               "edited", "closed", or "reopened". If the action is "closed" and the merged key is
#                               false, the pull request was closed with unmerged commits. If the action is "closed"
#                               and the merged key is true, the pull request was merged.
# number               integer  The pull request number.
# changes              object   The changes to the comment if the action was "edited".
# changes[title][from] string   The previous version of the title if the action was "edited".
# changes[body][from]  string   The previous version of the body if the action was "edited".
# pull_request         object   The pull request itself.
# `

# %%
events[events['type'] == 'PullRequestEvent'].head()
# Out:
#                  type                                            payload  \
# 127  PullRequestEvent  {u'action': u'closed', u'number': 196, u'pull_...
# 128  PullRequestEvent  {u'action': u'opened', u'number': 158, u'pull_...
# 129  PullRequestEvent  {u'action': u'opened', u'number': 127, u'pull_...
# 268  PullRequestEvent  {u'action': u'opened', u'number': 96, u'pull_r...
# 269  PullRequestEvent  {u'action': u'closed', u'number': 66, u'pull_r...
#
#       repo_id  user_id           login               created_at  archive_id
# 127  58482213  2467194     yoshuawuyts  2016-07-27 10:00:21 UTC  4333251316
# 128  50261548  5373549     mehmandarov  2016-07-09 13:10:32 UTC  4255480534
# 129  63730796  1134310  rodrigograca31  2016-07-22 17:07:21 UTC  4315231077
# 268  50261548  7223349        tombusby  2016-05-09 14:13:18 UTC  3989494180
# 269  50261548  2743180   sergiokopplin  2016-03-03 20:50:55 UTC  3719640122

# %%
pr_payload = pd.DataFrame(events['payload'][events['type'] == 'PullRequestEvent'].tolist())

# %%
pr_payload['action'].unique()
# Out:
# array([u'closed', u'opened', u'reopened'], dtype=object)

# %%
pr_payload_pr = pd.DataFrame(pr_payload['pull_request'].tolist())

# %%
pr_payload_pr.head()
# Out:
#                                               _links  additions assignee  \
# 0  {u'review_comment': {u'href': u'https://api.gi...          1     None
# 1  {u'review_comment': {u'href': u'https://api.gi...          3     None
# 2  {u'review_comment': {u'href': u'https://api.gi...          3     None
# 3  {u'review_comment': {u'href': u'https://api.gi...          1     None
# 4  {u'review_comment': {u'href': u'https://api.gi...         13     None
#
#   assignees                                               base  \
# 0        []  {u'repo': {u'issues_url': u'https://api.github...
# 1        []  {u'repo': {u'issues_url': u'https://api.github...
# 2        []  {u'repo': {u'issues_url': u'https://api.github...
# 3       NaN  {u'repo': {u'issues_url': u'https://api.github...
# 4       NaN  {u'repo': {u'issues_url': u'https://api.github...
#
#                                                 body  changed_files  \
# 0  The requirebin demo was also in the example ar...              1
# 1                                                                 1
# 2  A simple contribution to make the URL clickabl...              1
# 3  I was making a couple of alterations to main.c...              2
# 4  I needed an icon for my Medium.com account, so...              5
#
#               closed_at  comments  \
# 0  2016-07-27T10:00:21Z         1
# 1                  None         0
# 2                  None         0
# 3                  None         0
# 4  2016-03-03T20:50:54Z         1
#
#                                         comments_url  \
# 0  https://api.github.com/repos/yoshuawuyts/choo/...
# 1  https://api.github.com/repos/sergiokopplin/ind...
# 2  https://api.github.com/repos/mchristopher/Poke...
# 3  https://api.github.com/repos/sergiokopplin/ind...
# 4  https://api.github.com/repos/sergiokopplin/ind...
#
#                          ...                          requested_reviewers  \
# 0                        ...                                          NaN
# 1                        ...                                          NaN
# 2                        ...                                          NaN
# 3                        ...                                          NaN
# 4                        ...                                          NaN
#
#                                   review_comment_url review_comments  \
# 0  https://api.github.com/repos/yoshuawuyts/choo/...               0
# 1  https://api.github.com/repos/sergiokopplin/ind...               0
# 2  https://api.github.com/repos/mchristopher/Poke...               0
# 3  https://api.github.com/repos/sergiokopplin/ind...               0
# 4  https://api.github.com/repos/sergiokopplin/ind...               0
#
#                                  review_comments_url   state  \
# 0  https://api.github.com/repos/yoshuawuyts/choo/...  closed
# 1  https://api.github.com/repos/sergiokopplin/ind...    open
# 2  https://api.github.com/repos/mchristopher/Poke...    open
# 3  https://api.github.com/repos/sergiokopplin/ind...    open
# 4  https://api.github.com/repos/sergiokopplin/ind...  closed
#
#                                         statuses_url  \
# 0  https://api.github.com/repos/yoshuawuyts/choo/...
# 1  https://api.github.com/repos/sergiokopplin/ind...
# 2  https://api.github.com/repos/mchristopher/Poke...
# 3  https://api.github.com/repos/sergiokopplin/ind...
# 4  https://api.github.com/repos/sergiokopplin/ind...
#
#                                                title            updated_at  \
# 0                             Update link to example  2016-07-27T10:00:21Z
# 1             Minor changes. Typo fixes and cleanup.  2016-07-09T13:10:32Z
# 2                             Make the URL clickable  2016-07-22T17:07:21Z
# 3  Allow css caching and fix orphaned assets/styl...  2016-05-09T14:13:17Z
# 4  Added a social icon for Medium.com writing pla...  2016-03-03T20:50:54Z
#
#                                                  url  \
# 0  https://api.github.com/repos/yoshuawuyts/choo/...
# 1  https://api.github.com/repos/sergiokopplin/ind...
# 2  https://api.github.com/repos/mchristopher/Poke...
# 3  https://api.github.com/repos/sergiokopplin/ind...
# 4  https://api.github.com/repos/sergiokopplin/ind...
#
#                                                 user
# 0  {u'following_url': u'https://api.github.com/us...
# 1  {u'following_url': u'https://api.github.com/us...
# 2  {u'following_url': u'https://api.github.com/us...
# 3  {u'following_url': u'https://api.github.com/us...
# 4  {u'following_url': u'https://api.github.com/us...
#
# [5 rows x 41 columns]

# %%
pr_payload_pr.columns
# Out:
# Index([u'_links', u'additions', u'assignee', u'assignees', u'base', u'body',
#        u'changed_files', u'closed_at', u'comments', u'comments_url',
#        u'commits', u'commits_url', u'created_at', u'deletions', u'diff_url',
#        u'head', u'html_url', u'id', u'issue_url', u'locked',
#        u'maintainer_can_modify', u'merge_commit_sha', u'mergeable',
#        u'mergeable_state', u'merged', u'merged_at', u'merged_by', u'milestone',
#        u'number', u'patch_url', u'rebaseable', u'requested_reviewers',
#        u'review_comment_url', u'review_comments', u'review_comments_url',
#        u'state', u'statuses_url', u'title', u'updated_at', u'url', u'user'],
#       dtype='object')

# %%
pr_payload_pr[['commits', 'commits_url', 'created_at', 'deletions', 'diff_url',
       'head', 'html_url', 'id', 'issue_url', 'locked',
       'maintainer_can_modify', 'merge_commit_sha', 'mergeable',
       'mergeable_state', 'merged', 'merged_at', 'merged_by', 'milestone',
       'number', 'patch_url', 'rebaseable']].head()
# Out:
#    commits                                        commits_url  \
# 0        1  https://api.github.com/repos/yoshuawuyts/choo/...
# 1        1  https://api.github.com/repos/sergiokopplin/ind...
# 2        1  https://api.github.com/repos/mchristopher/Poke...
# 3        1  https://api.github.com/repos/sergiokopplin/ind...
# 4        3  https://api.github.com/repos/sergiokopplin/ind...
#
#              created_at  deletions  \
# 0  2016-07-25T18:39:12Z          1
# 1  2016-07-09T13:10:32Z          3
# 2  2016-07-22T17:07:21Z          1
# 3  2016-05-09T14:13:16Z       1188
# 4  2016-03-03T20:10:00Z          0
#
#                                             diff_url  \
# 0  https://github.com/yoshuawuyts/choo/pull/196.diff
# 1  https://github.com/sergiokopplin/indigo/pull/1...
# 2  https://github.com/mchristopher/PokemonGo-Desk...
# 3  https://github.com/sergiokopplin/indigo/pull/9...
# 4  https://github.com/sergiokopplin/indigo/pull/6...
#
#                                                 head  \
# 0  {u'repo': {u'issues_url': u'https://api.github...
# 1  {u'repo': {u'issues_url': u'https://api.github...
# 2  {u'repo': {u'issues_url': u'https://api.github...
# 3  {u'repo': {u'issues_url': u'https://api.github...
# 4  {u'repo': {u'issues_url': u'https://api.github...
#
#                                             html_url        id  \
# 0       https://github.com/yoshuawuyts/choo/pull/196  78730407
# 1   https://github.com/sergiokopplin/indigo/pull/158  76846611
# 2  https://github.com/mchristopher/PokemonGo-Desk...  78509356
# 3    https://github.com/sergiokopplin/indigo/pull/96  69351580
# 4    https://github.com/sergiokopplin/indigo/pull/66  61617351
#
#                                            issue_url locked    ...      \
# 0  https://api.github.com/repos/yoshuawuyts/choo/...  False    ...
# 1  https://api.github.com/repos/sergiokopplin/ind...  False    ...
# 2  https://api.github.com/repos/mchristopher/Poke...  False    ...
# 3  https://api.github.com/repos/sergiokopplin/ind...  False    ...
# 4  https://api.github.com/repos/sergiokopplin/ind...  False    ...
#
#                            merge_commit_sha mergeable mergeable_state merged  \
# 0  d547d5863bf3b50502910110c17d197619842b27      None         unknown   True
# 1                                      None      None         unknown  False
# 2                                      None      None         unknown  False
# 3                                      None      None         unknown  False
# 4  6a86bde259c541af2e5163e1feb053d246a9744d      None         unknown   True
#
#               merged_at                                          merged_by  \
# 0  2016-07-27T10:00:21Z  {u'following_url': u'https://api.github.com/us...
# 1                  None                                               None
# 2                  None                                               None
# 3                  None                                               None
# 4  2016-03-03T20:50:54Z  {u'following_url': u'https://api.github.com/us...
#
#   milestone number                                          patch_url  \
# 0      None    196  https://github.com/yoshuawuyts/choo/pull/196.p...
# 1      None    158  https://github.com/sergiokopplin/indigo/pull/1...
# 2      None    127  https://github.com/mchristopher/PokemonGo-Desk...
# 3      None     96  https://github.com/sergiokopplin/indigo/pull/9...
# 4      None     66  https://github.com/sergiokopplin/indigo/pull/6...
#
#   rebaseable
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 21 columns]

# %%
pr_payload_pr['merged_by'].iloc[0]
# Out:
# {u'avatar_url': u'https://avatars.githubusercontent.com/u/2467194?v=3',
#  u'events_url': u'https://api.github.com/users/yoshuawuyts/events{/privacy}',
#  u'followers_url': u'https://api.github.com/users/yoshuawuyts/followers',
#  u'following_url': u'https://api.github.com/users/yoshuawuyts/following{/other_user}',
#  u'gists_url': u'https://api.github.com/users/yoshuawuyts/gists{/gist_id}',
#  u'gravatar_id': u'',
#  u'html_url': u'https://github.com/yoshuawuyts',
#  u'id': 2467194,
#  u'login': u'yoshuawuyts',
#  u'organizations_url': u'https://api.github.com/users/yoshuawuyts/orgs',
#  u'received_events_url': u'https://api.github.com/users/yoshuawuyts/received_events',
#  u'repos_url': u'https://api.github.com/users/yoshuawuyts/repos',
#  u'site_admin': False,
#  u'starred_url': u'https://api.github.com/users/yoshuawuyts/starred{/owner}{/repo}',
#  u'subscriptions_url': u'https://api.github.com/users/yoshuawuyts/subscriptions',
#  u'type': u'User',
#  u'url': u'https://api.github.com/users/yoshuawuyts'}

# %%
pr_payload_pr['head'].iloc[0]
# Out:
# {u'label': u'MattMcFarland:patch-2',
#  u'ref': u'patch-2',
#  u'repo': {u'archive_url': u'https://api.github.com/repos/MattMcFarland/choo/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/MattMcFarland/choo/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/MattMcFarland/choo/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/MattMcFarland/choo/branches{/branch}',
#   u'clone_url': u'https://github.com/MattMcFarland/choo.git',
#   u'collaborators_url': u'https://api.github.com/repos/MattMcFarland/choo/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/MattMcFarland/choo/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/MattMcFarland/choo/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/MattMcFarland/choo/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/MattMcFarland/choo/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/MattMcFarland/choo/contributors',
#   u'created_at': u'2016-07-21T13:39:04Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/MattMcFarland/choo/deployments',
#   u'description': u':steam_locomotive::train::train::train: - sturdy frontend framework',
#   u'downloads_url': u'https://api.github.com/repos/MattMcFarland/choo/downloads',
#   u'events_url': u'https://api.github.com/repos/MattMcFarland/choo/events',
#   u'fork': True,
#   u'forks': 0,
#   u'forks_count': 0,
#   u'forks_url': u'https://api.github.com/repos/MattMcFarland/choo/forks',
#   u'full_name': u'MattMcFarland/choo',
#   u'git_commits_url': u'https://api.github.com/repos/MattMcFarland/choo/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/MattMcFarland/choo/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/MattMcFarland/choo/git/tags{/sha}',
#   u'git_url': u'git://github.com/MattMcFarland/choo.git',
#   u'has_downloads': True,
#   u'has_issues': False,
#   u'has_pages': False,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/MattMcFarland/choo/hooks',
#   u'html_url': u'https://github.com/MattMcFarland/choo',
#   u'id': 63872469,
#   u'issue_comment_url': u'https://api.github.com/repos/MattMcFarland/choo/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/MattMcFarland/choo/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/MattMcFarland/choo/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/MattMcFarland/choo/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/MattMcFarland/choo/labels{/name}',
#   u'language': u'JavaScript',
#   u'languages_url': u'https://api.github.com/repos/MattMcFarland/choo/languages',
#   u'merges_url': u'https://api.github.com/repos/MattMcFarland/choo/merges',
#   u'milestones_url': u'https://api.github.com/repos/MattMcFarland/choo/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'choo',
#   u'notifications_url': u'https://api.github.com/repos/MattMcFarland/choo/notifications{?since,all,participating}',
#   u'open_issues': 0,
#   u'open_issues_count': 0,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/623545?v=3',
#    u'events_url': u'https://api.github.com/users/MattMcFarland/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/MattMcFarland/followers',
#    u'following_url': u'https://api.github.com/users/MattMcFarland/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/MattMcFarland/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/MattMcFarland',
#    u'id': 623545,
#    u'login': u'MattMcFarland',
#    u'organizations_url': u'https://api.github.com/users/MattMcFarland/orgs',
#    u'received_events_url': u'https://api.github.com/users/MattMcFarland/received_events',
#    u'repos_url': u'https://api.github.com/users/MattMcFarland/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/MattMcFarland/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/MattMcFarland/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/MattMcFarland'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/MattMcFarland/choo/pulls{/number}',
#   u'pushed_at': u'2016-07-25T18:39:06Z',
#   u'releases_url': u'https://api.github.com/repos/MattMcFarland/choo/releases{/id}',
#   u'size': 327,
#   u'ssh_url': u'git@github.com:MattMcFarland/choo.git',
#   u'stargazers_count': 0,
#   u'stargazers_url': u'https://api.github.com/repos/MattMcFarland/choo/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/MattMcFarland/choo/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/MattMcFarland/choo/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/MattMcFarland/choo/subscription',
#   u'svn_url': u'https://github.com/MattMcFarland/choo',
#   u'tags_url': u'https://api.github.com/repos/MattMcFarland/choo/tags',
#   u'teams_url': u'https://api.github.com/repos/MattMcFarland/choo/teams',
#   u'trees_url': u'https://api.github.com/repos/MattMcFarland/choo/git/trees{/sha}',
#   u'updated_at': u'2016-07-21T13:39:05Z',
#   u'url': u'https://api.github.com/repos/MattMcFarland/choo',
#   u'watchers': 0,
#   u'watchers_count': 0},
#  u'sha': u'6aa88da861783d11efddae59a1cd3fcf7a5f9de7',
#  u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/623545?v=3',
#   u'events_url': u'https://api.github.com/users/MattMcFarland/events{/privacy}',
#   u'followers_url': u'https://api.github.com/users/MattMcFarland/followers',
#   u'following_url': u'https://api.github.com/users/MattMcFarland/following{/other_user}',
#   u'gists_url': u'https://api.github.com/users/MattMcFarland/gists{/gist_id}',
#   u'gravatar_id': u'',
#   u'html_url': u'https://github.com/MattMcFarland',
#   u'id': 623545,
#   u'login': u'MattMcFarland',
#   u'organizations_url': u'https://api.github.com/users/MattMcFarland/orgs',
#   u'received_events_url': u'https://api.github.com/users/MattMcFarland/received_events',
#   u'repos_url': u'https://api.github.com/users/MattMcFarland/repos',
#   u'site_admin': False,
#   u'starred_url': u'https://api.github.com/users/MattMcFarland/starred{/owner}{/repo}',
#   u'subscriptions_url': u'https://api.github.com/users/MattMcFarland/subscriptions',
#   u'type': u'User',
#   u'url': u'https://api.github.com/users/MattMcFarland'}}

# %%
pr_payload_pr['_links'].iloc[0]
# Out:
# {u'comments': {u'href': u'https://api.github.com/repos/yoshuawuyts/choo/issues/196/comments'},
#  u'commits': {u'href': u'https://api.github.com/repos/yoshuawuyts/choo/pulls/196/commits'},
#  u'html': {u'href': u'https://github.com/yoshuawuyts/choo/pull/196'},
#  u'issue': {u'href': u'https://api.github.com/repos/yoshuawuyts/choo/issues/196'},
#  u'review_comment': {u'href': u'https://api.github.com/repos/yoshuawuyts/choo/pulls/comments{/number}'},
#  u'review_comments': {u'href': u'https://api.github.com/repos/yoshuawuyts/choo/pulls/196/comments'},
#  u'self': {u'href': u'https://api.github.com/repos/yoshuawuyts/choo/pulls/196'},
#  u'statuses': {u'href': u'https://api.github.com/repos/yoshuawuyts/choo/statuses/6aa88da861783d11efddae59a1cd3fcf7a5f9de7'}}

# %%
pr_payload_pr['base'].iloc[0]
# Out:
# {u'label': u'yoshuawuyts:master',
#  u'ref': u'master',
#  u'repo': {u'archive_url': u'https://api.github.com/repos/yoshuawuyts/choo/{archive_format}{/ref}',
#   u'assignees_url': u'https://api.github.com/repos/yoshuawuyts/choo/assignees{/user}',
#   u'blobs_url': u'https://api.github.com/repos/yoshuawuyts/choo/git/blobs{/sha}',
#   u'branches_url': u'https://api.github.com/repos/yoshuawuyts/choo/branches{/branch}',
#   u'clone_url': u'https://github.com/yoshuawuyts/choo.git',
#   u'collaborators_url': u'https://api.github.com/repos/yoshuawuyts/choo/collaborators{/collaborator}',
#   u'comments_url': u'https://api.github.com/repos/yoshuawuyts/choo/comments{/number}',
#   u'commits_url': u'https://api.github.com/repos/yoshuawuyts/choo/commits{/sha}',
#   u'compare_url': u'https://api.github.com/repos/yoshuawuyts/choo/compare/{base}...{head}',
#   u'contents_url': u'https://api.github.com/repos/yoshuawuyts/choo/contents/{+path}',
#   u'contributors_url': u'https://api.github.com/repos/yoshuawuyts/choo/contributors',
#   u'created_at': u'2016-05-10T17:50:35Z',
#   u'default_branch': u'master',
#   u'deployments_url': u'https://api.github.com/repos/yoshuawuyts/choo/deployments',
#   u'description': u':steam_locomotive::train::train::train: - sturdy frontend framework',
#   u'downloads_url': u'https://api.github.com/repos/yoshuawuyts/choo/downloads',
#   u'events_url': u'https://api.github.com/repos/yoshuawuyts/choo/events',
#   u'fork': False,
#   u'forks': 73,
#   u'forks_count': 73,
#   u'forks_url': u'https://api.github.com/repos/yoshuawuyts/choo/forks',
#   u'full_name': u'yoshuawuyts/choo',
#   u'git_commits_url': u'https://api.github.com/repos/yoshuawuyts/choo/git/commits{/sha}',
#   u'git_refs_url': u'https://api.github.com/repos/yoshuawuyts/choo/git/refs{/sha}',
#   u'git_tags_url': u'https://api.github.com/repos/yoshuawuyts/choo/git/tags{/sha}',
#   u'git_url': u'git://github.com/yoshuawuyts/choo.git',
#   u'has_downloads': True,
#   u'has_issues': True,
#   u'has_pages': False,
#   u'has_wiki': True,
#   u'homepage': u'',
#   u'hooks_url': u'https://api.github.com/repos/yoshuawuyts/choo/hooks',
#   u'html_url': u'https://github.com/yoshuawuyts/choo',
#   u'id': 58482213,
#   u'issue_comment_url': u'https://api.github.com/repos/yoshuawuyts/choo/issues/comments{/number}',
#   u'issue_events_url': u'https://api.github.com/repos/yoshuawuyts/choo/issues/events{/number}',
#   u'issues_url': u'https://api.github.com/repos/yoshuawuyts/choo/issues{/number}',
#   u'keys_url': u'https://api.github.com/repos/yoshuawuyts/choo/keys{/key_id}',
#   u'labels_url': u'https://api.github.com/repos/yoshuawuyts/choo/labels{/name}',
#   u'language': u'JavaScript',
#   u'languages_url': u'https://api.github.com/repos/yoshuawuyts/choo/languages',
#   u'merges_url': u'https://api.github.com/repos/yoshuawuyts/choo/merges',
#   u'milestones_url': u'https://api.github.com/repos/yoshuawuyts/choo/milestones{/number}',
#   u'mirror_url': None,
#   u'name': u'choo',
#   u'notifications_url': u'https://api.github.com/repos/yoshuawuyts/choo/notifications{?since,all,participating}',
#   u'open_issues': 27,
#   u'open_issues_count': 27,
#   u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/2467194?v=3',
#    u'events_url': u'https://api.github.com/users/yoshuawuyts/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/yoshuawuyts/followers',
#    u'following_url': u'https://api.github.com/users/yoshuawuyts/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/yoshuawuyts/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/yoshuawuyts',
#    u'id': 2467194,
#    u'login': u'yoshuawuyts',
#    u'organizations_url': u'https://api.github.com/users/yoshuawuyts/orgs',
#    u'received_events_url': u'https://api.github.com/users/yoshuawuyts/received_events',
#    u'repos_url': u'https://api.github.com/users/yoshuawuyts/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/yoshuawuyts/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/yoshuawuyts/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/yoshuawuyts'},
#   u'private': False,
#   u'pulls_url': u'https://api.github.com/repos/yoshuawuyts/choo/pulls{/number}',
#   u'pushed_at': u'2016-07-27T10:00:20Z',
#   u'releases_url': u'https://api.github.com/repos/yoshuawuyts/choo/releases{/id}',
#   u'size': 296,
#   u'ssh_url': u'git@github.com:yoshuawuyts/choo.git',
#   u'stargazers_count': 2166,
#   u'stargazers_url': u'https://api.github.com/repos/yoshuawuyts/choo/stargazers',
#   u'statuses_url': u'https://api.github.com/repos/yoshuawuyts/choo/statuses/{sha}',
#   u'subscribers_url': u'https://api.github.com/repos/yoshuawuyts/choo/subscribers',
#   u'subscription_url': u'https://api.github.com/repos/yoshuawuyts/choo/subscription',
#   u'svn_url': u'https://github.com/yoshuawuyts/choo',
#   u'tags_url': u'https://api.github.com/repos/yoshuawuyts/choo/tags',
#   u'teams_url': u'https://api.github.com/repos/yoshuawuyts/choo/teams',
#   u'trees_url': u'https://api.github.com/repos/yoshuawuyts/choo/git/trees{/sha}',
#   u'updated_at': u'2016-07-27T09:37:58Z',
#   u'url': u'https://api.github.com/repos/yoshuawuyts/choo',
#   u'watchers': 2166,
#   u'watchers_count': 2166},
#  u'sha': u'88a0816f5242a26296648eaf14f9114b2342fc66',
#  u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/2467194?v=3',
#   u'events_url': u'https://api.github.com/users/yoshuawuyts/events{/privacy}',
#   u'followers_url': u'https://api.github.com/users/yoshuawuyts/followers',
#   u'following_url': u'https://api.github.com/users/yoshuawuyts/following{/other_user}',
#   u'gists_url': u'https://api.github.com/users/yoshuawuyts/gists{/gist_id}',
#   u'gravatar_id': u'',
#   u'html_url': u'https://github.com/yoshuawuyts',
#   u'id': 2467194,
#   u'login': u'yoshuawuyts',
#   u'organizations_url': u'https://api.github.com/users/yoshuawuyts/orgs',
#   u'received_events_url': u'https://api.github.com/users/yoshuawuyts/received_events',
#   u'repos_url': u'https://api.github.com/users/yoshuawuyts/repos',
#   u'site_admin': False,
#   u'starred_url': u'https://api.github.com/users/yoshuawuyts/starred{/owner}{/repo}',
#   u'subscriptions_url': u'https://api.github.com/users/yoshuawuyts/subscriptions',
#   u'type': u'User',
#   u'url': u'https://api.github.com/users/yoshuawuyts'}}

# %%
pr_payload_pr['html_url'].iloc[0]
# Out:
# u'https://github.com/yoshuawuyts/choo/pull/196'

# %% [markdown]
# ## Create Event
# Represents a created repository, branch, or tag.
#
# `
# KEY            TYPE      DESCRIPTION
# ref_type       string	The object that was created. Can be one of "repository", "branch", or "tag"
# ref            string	The git ref (or null if only a repository was created).
# master_branch  string	The name of the repository's default branch (usually master).
# description    string	The repository's current description.
# `

# %%
CreateEvent = events[events['type'] == 'CreateEvent']

print CreateEvent.shape
# Out:
# (7752, 7)

# %%
CreateEvent['payload'].iloc[0]
# Out:
# {u'description': u'A statuspage generator that lets you host your statuspage for free on Github.',
#  u'master_branch': u'master',
#  u'pusher_type': u'user',
#  u'ref': u'pyup-update-pygithub-1.27.1-to-1.28',
#  u'ref_type': u'branch'}

# %%
create_table = pd.concat([CreateEvent.drop(['payload'], axis=1), CreateEvent['payload'].apply(pd.Series)], axis=1)

# %%
create_table.head()
# Out:
#             type   repo_id   user_id          login          created_at  \
# 106  CreateEvent  52598117   2930472          jayfk 2016-09-11 20:06:45
# 107  CreateEvent  50261548   2743180  sergiokopplin 2016-05-24 16:18:36
# 108  CreateEvent  51905436   4154003       dherault 2016-06-01 08:08:32
# 252  CreateEvent  59716022    633234        dwlfrth 2016-05-28 16:34:01
# 253  CreateEvent  66615835  12601115      egorbenko 2016-08-26 04:34:46
#
#      archive_id                                        description  \
# 106  4546427203  A statuspage generator that lets you host your...
# 107  4055726574                 :ramen: Minimalist Jekyll Template
# 108  4086935723  Emulate AWS  and API Gateway locally when deve...
# 252  4074681227                 :ramen: Minimalist Jekyll Template
# 253  4473514913  a lightweight artificially intelligent multi-e...
#
#     master_branch pusher_type                                  ref ref_type
# 106        master        user  pyup-update-pygithub-1.27.1-to-1.28   branch
# 107      gh-pages        user                                0.4.0      tag
# 108        master        user                               v2.5.1      tag
# 252      gh-pages        user                       fix/email_link   branch
# 253        master        user                               docker   branch

# %%
create_table_cols = ['repo_id', 'user_id', 'login', 'created_at', 'archive_id', 'description',
                     'master_branch', 'ref', 'ref_type']

create_table = create_table[create_table_cols]

# %%
create_table = create_table.rename(columns={'login': 'user_login', 'created_at':'date_created'})

# %%
# drop all duplicates across ALL columns
create_table = create_table.drop_duplicates()

print create_table.shape
# Out:
# (7748, 9)

# %%
create_create_table = '''
CREATE TABLE create_events (
    repo_id       NUMERIC      NOT NULL,
    date_created  TEXT         NOT NULL,
    master_branch VARCHAR (50) NOT NULL,
    ref_type      VARCHAR (15) NOT NULL,
    ref           TEXT,
    description   TEXT,
    user_id       NUMERIC      NOT NULL,
    user_login    VARCHAR (40) NOT NULL,
    archive_id    NUMERIC      NOT NULL,
    PRIMARY KEY (
        repo_id,
        user_id,
        archive_id
    )
)
WITHOUT ROWID;
'''

# %%
c.execute(create_create_table)
con.commit()

# %%
create_table.to_sql(name='create_events', con=con, if_exists='append', index=False)

# %% [markdown]
# ## Gollum Event
# Triggered when a Wiki page is created or updated.
#
# `
# KEY                TYPE    DESCRIPTION
# pages              array   The pages that were updated.
# pages[][page_name] string  The name of the page.
# pages[][title]     string  The current page title.
# pages[][action]    string  The action that was performed on the page. Can be "created" or "edited".
# pages[][sha]       string  The latest commit SHA of the page.
# pages[][html_url]  string  Points to the HTML wiki page.
# `

# %%
events[events['type'] == 'GollumEvent'].head()
# Out:
#             type                                            payload   repo_id  \
# 110  GollumEvent  {u'pages': [{u'title': u'Mudana de Regio', u'h...  56832437
# 111  GollumEvent  {u'pages': [{u'title': u'Home', u'html_url': u...  63730796
# 112  GollumEvent  {u'pages': [{u'title': u'Part 1 (Decrypt9)', u...  52920387
# 113  GollumEvent  {u'pages': [{u'title': u'Part 3 (RedNAND)', u'...  58546876
# 114  GollumEvent  {u'pages': [{u'title': u'Part 1 (Decrypt9)', u...  52920387
#
#       user_id           login               created_at  archive_id
# 110  10860756  HenryLeonheart  2016-04-25 10:09:09 UTC  3930925431
# 111  20782190         MacDogg  2016-08-02 15:57:48 UTC  4360926496
# 112  16979510        Plailect  2016-09-14 12:48:42 UTC  4561726421
# 113  12843673       KonsoleHL  2016-06-10 17:21:42 UTC  4131124722
# 114  16979510        Plailect  2016-08-27 19:33:32 UTC  4479691144

# %%
events['payload'][events['type'] == 'GollumEvent'].iloc[0]
# Out:
# {u'pages': [{u'action': u'edited',
#    u'html_url': u'/HenryLeonheart/Guide_Portuguese/wiki/Mudan%C3%A7a-de-Regi%C3%A3o',
#    u'page_name': u'Mudana-de-Regio',
#    u'sha': u'fe9d278b7d921f92b6f4cfb4321717d23cc51acf',
#    u'summary': None,
#    u'title': u'Mudana de Regio'}]}

# %% [markdown]
# ## Delete Event
# Represents a deleted branch or tag.
#
# `
# KEY         TYPE    DESCRIPTION
# ref_type    string  The object that was deleted. Can be "branch" or "tag".
# ref         string  The full git ref.
# `

# %%
DeleteEvents = events[events['type'] == 'DeleteEvent']

# %%
delete_table = pd.concat([DeleteEvents.drop(['payload'], axis=1), DeleteEvents['payload'].apply(pd.Series)], axis=1)

# %%
print delete_table.shape

delete_table.head()
# Out:
# (3745, 9)
#             type   repo_id  user_id         login          created_at  \
# 109  DeleteEvent  50340470  4172932  KunalKapadia 2016-10-12 11:31:05
# 397  DeleteEvent  58482213  2467194   yoshuawuyts 2016-10-28 00:54:28
# 398  DeleteEvent  67534988  6452882      mcrowson 2016-12-14 14:16:43
# 542  DeleteEvent  61498284  3019665     jakirkham 2016-11-30 15:11:15
# 702  DeleteEvent  70114942  5995907        bebaps 2016-12-09 01:08:08
#
#      archive_id pusher_type                                      ref ref_type
# 109  4698047202        user  greenkeeper-babel-preset-stage-2-6.17.0   branch
# 397  4779948081        user                            rm-hash-match   branch
# 398  5020199929        user           doppins/botocore-equals-1.4.30   branch
# 542  4946666703        user                   skip_no_change_upgrade   branch
# 702  4993725855        user                                 gh-pages   branch

# %%
delete_table_cols = ['repo_id', 'user_id', 'login', 'created_at', 'archive_id', 'ref', 'ref_type']

delete_table = delete_table[delete_table_cols]

# %%
delete_table = delete_table.rename(columns={'created_at': 'date_deleted', 'login':'user_login'})

# %%
delete_table = delete_table.drop_duplicates()

print delete_table.shape
# Out:
# (3737, 7)

# %%
create_delete_table = '''
CREATE TABLE delete_events (
    repo_id      NUMERIC      NOT NULL,
    date_deleted TEXT         NOT NULL,
    ref_type     VARCHAR (15) NOT NULL,
    ref          TEXT,
    user_id      NUMERIC      NOT NULL,
    user_login   VARCHAR (40) NOT NULL,
    archive_id   NUMERIC      NOT NULL,
    PRIMARY KEY (
        repo_id,
        user_id,
        date_deleted,
        ref
    )
)
WITHOUT ROWID;
'''

# %%
c.execute(create_delete_table)
con.commit()

# %%
delete_table.to_sql(name='delete_events', con=con, if_exists='append', index=False)

# %% [markdown]
# ## Pull Request Review Comment Event
# Triggered when a comment on a pull request's unified diff is created, edited, or deleted (in the Files Changed tab).
#
# `
# KEY                  TYPE    DESCRIPTION
# action               string  The action that was performed on the comment. Can be one of "created", "edited", or
#                              "deleted".
# changes              object  The changes to the comment if the action was "edited".
# changes[body][from]  string  The previous version of the body if the action was "edited".
# pull_request         object  The pull request the comment belongs to.
# comment              object  The comment itself.
# `

# %%
events[events['type'] == 'PullRequestReviewCommentEvent'].head()
# Out:
#                               type  \
# 157  PullRequestReviewCommentEvent
# 158  PullRequestReviewCommentEvent
# 290  PullRequestReviewCommentEvent
# 441  PullRequestReviewCommentEvent
# 593  PullRequestReviewCommentEvent
#
#                                                payload   repo_id  user_id  \
# 157  {u'action': u'created', u'comment': {u'origina...  51769689   170270
# 158  {u'action': u'created', u'comment': {u'origina...  51769689   737065
# 290  {u'action': u'created', u'comment': {u'origina...  51769689   737065
# 441  {u'action': u'created', u'comment': {u'origina...  51769689   228037
# 593  {u'action': u'created', u'comment': {u'origina...  50063252   399441
#
#             login               created_at  archive_id
# 157  sindresorhus  2016-06-17 23:58:49 UTC  4163151005
# 158  paulmolluzzo  2016-04-05 01:03:36 UTC  3845956436
# 290  paulmolluzzo  2016-05-14 12:49:23 UTC  4014735110
# 441      blackjid  2016-03-30 22:50:31 UTC  3827449219
# 593        mathom  2016-07-06 17:02:57 UTC  4241678868

# %%
events['payload'][events['type'] == 'PullRequestReviewCommentEvent'].iloc[0]
# Out:
# {u'action': u'created',
#  u'comment': {u'_links': {u'html': {u'href': u'https://github.com/sindresorhus/refined-github/pull/251#discussion_r67589649'},
#    u'pull_request': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/251'},
#    u'self': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/comments/67589649'}},
#   u'body': u'Oh, ok. Just never seen `createContextualFragment` used before.\r\n\r\nI think I would rather do:\r\n\r\n```js\r\n(new DOMParser()).parseFromString(\'<!DOCTYPE html><html lang="en"><body><p></p></body></html>\', \'text/html\');\r\n```',
#   u'commit_id': u'a4af7b1c41e6850a1d0ae86e471840a3d28341b4',
#   u'created_at': u'2016-06-17T23:58:49Z',
#   u'diff_hunk': u'@@ -0,0 +1,56 @@\n+window.showRealNames = () => {\n+\tconst storageKey = \'cachedNames\';\n+\n+\tconst getCachedUsers = cb => {\n+\t\tchrome.storage.local.get(storageKey, data => cb(data[storageKey]));\n+\t};\n+\n+\tconst updateCachedUsers = users => {\n+\t\tchrome.storage.local.set({[storageKey]: users});\n+\t};\n+\n+\tconst addUsersName = (user, name) => {\n+\t\tconst $usernameLinks = $(`.timeline-comment-header-text:not(.has-full-name) a[href="/${user}"]`);\n+\t\t$usernameLinks.each((i, userLink) => {\n+\t\t\t$(`<span class="comment-full-name">${name} -</span>`).insertAfter(userLink);\n+\t\t\t$(userLink).closest(\'.timeline-comment-header-text\').addClass(\'has-full-name\');\n+\t\t});\n+\t};\n+\n+\tgetCachedUsers((users = {}) => {\n+\t\tconst usersOnPage = $(\'.js-discussion .author\').dom.map(el => el.innerText);\n+\t\tconst uniqueUsers = new Set(usersOnPage);\n+\n+\t\t// Add cached users to DOM first, since the calls for everyone else will be slow\n+\t\tfor (const user of uniqueUsers) {\n+\t\t\tconst cachedName = users[user];\n+\t\t\tif (cachedName) {\n+\t\t\t\taddUsersName(user, cachedName);\n+\t\t\t\tuniqueUsers.delete(user);\n+\t\t\t}\n+\t\t}\n+\n+\t\tconst userUrl = user => `https://github.com/${user}/following`;\n+\t\tconst requests = Array.from(uniqueUsers).map(user => fetch(userUrl(user)).then(res => res.text()));\n+\t\tPromise.all(requests).then(profiles => {\n+\t\t\tconst userCache = {};\n+\n+\t\t\tfor (const profile of profiles) {\n+\t\t\t\t// `createContextualFragment` because Sprint/jQuery $ fn treats an entire HTML document as one giant text node',
#   u'html_url': u'https://github.com/sindresorhus/refined-github/pull/251#discussion_r67589649',
#   u'id': 67589649,
#   u'original_commit_id': u'a4af7b1c41e6850a1d0ae86e471840a3d28341b4',
#   u'original_position': 39,
#   u'path': u'extension/show-names.js',
#   u'position': 39,
#   u'pull_request_url': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/251',
#   u'updated_at': u'2016-06-17T23:58:49Z',
#   u'url': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/comments/67589649',
#   u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/170270?v=3',
#    u'events_url': u'https://api.github.com/users/sindresorhus/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/sindresorhus/followers',
#    u'following_url': u'https://api.github.com/users/sindresorhus/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/sindresorhus/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/sindresorhus',
#    u'id': 170270,
#    u'login': u'sindresorhus',
#    u'organizations_url': u'https://api.github.com/users/sindresorhus/orgs',
#    u'received_events_url': u'https://api.github.com/users/sindresorhus/received_events',
#    u'repos_url': u'https://api.github.com/users/sindresorhus/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/sindresorhus/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/sindresorhus/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/sindresorhus'}},
#  u'pull_request': {u'_links': {u'comments': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/issues/251/comments'},
#    u'commits': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/251/commits'},
#    u'html': {u'href': u'https://github.com/sindresorhus/refined-github/pull/251'},
#    u'issue': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/issues/251'},
#    u'review_comment': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/comments{/number}'},
#    u'review_comments': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/251/comments'},
#    u'self': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/251'},
#    u'statuses': {u'href': u'https://api.github.com/repos/sindresorhus/refined-github/statuses/a4af7b1c41e6850a1d0ae86e471840a3d28341b4'}},
#   u'assignee': None,
#   u'base': {u'label': u'sindresorhus:master',
#    u'ref': u'master',
#    u'repo': {u'archive_url': u'https://api.github.com/repos/sindresorhus/refined-github/{archive_format}{/ref}',
#     u'assignees_url': u'https://api.github.com/repos/sindresorhus/refined-github/assignees{/user}',
#     u'blobs_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/blobs{/sha}',
#     u'branches_url': u'https://api.github.com/repos/sindresorhus/refined-github/branches{/branch}',
#     u'clone_url': u'https://github.com/sindresorhus/refined-github.git',
#     u'collaborators_url': u'https://api.github.com/repos/sindresorhus/refined-github/collaborators{/collaborator}',
#     u'comments_url': u'https://api.github.com/repos/sindresorhus/refined-github/comments{/number}',
#     u'commits_url': u'https://api.github.com/repos/sindresorhus/refined-github/commits{/sha}',
#     u'compare_url': u'https://api.github.com/repos/sindresorhus/refined-github/compare/{base}...{head}',
#     u'contents_url': u'https://api.github.com/repos/sindresorhus/refined-github/contents/{+path}',
#     u'contributors_url': u'https://api.github.com/repos/sindresorhus/refined-github/contributors',
#     u'created_at': u'2016-02-15T16:45:02Z',
#     u'default_branch': u'master',
#     u'deployments_url': u'https://api.github.com/repos/sindresorhus/refined-github/deployments',
#     u'description': u'Chrome extension that simplifies the GitHub interface and adds useful features',
#     u'downloads_url': u'https://api.github.com/repos/sindresorhus/refined-github/downloads',
#     u'events_url': u'https://api.github.com/repos/sindresorhus/refined-github/events',
#     u'fork': False,
#     u'forks': 60,
#     u'forks_count': 60,
#     u'forks_url': u'https://api.github.com/repos/sindresorhus/refined-github/forks',
#     u'full_name': u'sindresorhus/refined-github',
#     u'git_commits_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/commits{/sha}',
#     u'git_refs_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/refs{/sha}',
#     u'git_tags_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/tags{/sha}',
#     u'git_url': u'git://github.com/sindresorhus/refined-github.git',
#     u'has_downloads': True,
#     u'has_issues': True,
#     u'has_pages': False,
#     u'has_wiki': False,
#     u'homepage': u'https://chrome.google.com/webstore/detail/refined-github/hlepfoohegkhhmjieoechaddaejaokhf',
#     u'hooks_url': u'https://api.github.com/repos/sindresorhus/refined-github/hooks',
#     u'html_url': u'https://github.com/sindresorhus/refined-github',
#     u'id': 51769689,
#     u'issue_comment_url': u'https://api.github.com/repos/sindresorhus/refined-github/issues/comments{/number}',
#     u'issue_events_url': u'https://api.github.com/repos/sindresorhus/refined-github/issues/events{/number}',
#     u'issues_url': u'https://api.github.com/repos/sindresorhus/refined-github/issues{/number}',
#     u'keys_url': u'https://api.github.com/repos/sindresorhus/refined-github/keys{/key_id}',
#     u'labels_url': u'https://api.github.com/repos/sindresorhus/refined-github/labels{/name}',
#     u'language': u'JavaScript',
#     u'languages_url': u'https://api.github.com/repos/sindresorhus/refined-github/languages',
#     u'merges_url': u'https://api.github.com/repos/sindresorhus/refined-github/merges',
#     u'milestones_url': u'https://api.github.com/repos/sindresorhus/refined-github/milestones{/number}',
#     u'mirror_url': None,
#     u'name': u'refined-github',
#     u'notifications_url': u'https://api.github.com/repos/sindresorhus/refined-github/notifications{?since,all,participating}',
#     u'open_issues': 41,
#     u'open_issues_count': 41,
#     u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/170270?v=3',
#      u'events_url': u'https://api.github.com/users/sindresorhus/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/sindresorhus/followers',
#      u'following_url': u'https://api.github.com/users/sindresorhus/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/sindresorhus/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/sindresorhus',
#      u'id': 170270,
#      u'login': u'sindresorhus',
#      u'organizations_url': u'https://api.github.com/users/sindresorhus/orgs',
#      u'received_events_url': u'https://api.github.com/users/sindresorhus/received_events',
#      u'repos_url': u'https://api.github.com/users/sindresorhus/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/sindresorhus/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/sindresorhus/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/sindresorhus'},
#     u'private': False,
#     u'pulls_url': u'https://api.github.com/repos/sindresorhus/refined-github/pulls{/number}',
#     u'pushed_at': u'2016-06-17T23:45:09Z',
#     u'releases_url': u'https://api.github.com/repos/sindresorhus/refined-github/releases{/id}',
#     u'size': 1712,
#     u'ssh_url': u'git@github.com:sindresorhus/refined-github.git',
#     u'stargazers_count': 781,
#     u'stargazers_url': u'https://api.github.com/repos/sindresorhus/refined-github/stargazers',
#     u'statuses_url': u'https://api.github.com/repos/sindresorhus/refined-github/statuses/{sha}',
#     u'subscribers_url': u'https://api.github.com/repos/sindresorhus/refined-github/subscribers',
#     u'subscription_url': u'https://api.github.com/repos/sindresorhus/refined-github/subscription',
#     u'svn_url': u'https://github.com/sindresorhus/refined-github',
#     u'tags_url': u'https://api.github.com/repos/sindresorhus/refined-github/tags',
#     u'teams_url': u'https://api.github.com/repos/sindresorhus/refined-github/teams',
#     u'trees_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/trees{/sha}',
#     u'updated_at': u'2016-06-17T21:29:24Z',
#     u'url': u'https://api.github.com/repos/sindresorhus/refined-github',
#     u'watchers': 781,
#     u'watchers_count': 781},
#    u'sha': u'9b095d2c9cd7067f1df984a4eeea787d9e574310',
#    u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/170270?v=3',
#     u'events_url': u'https://api.github.com/users/sindresorhus/events{/privacy}',
#     u'followers_url': u'https://api.github.com/users/sindresorhus/followers',
#     u'following_url': u'https://api.github.com/users/sindresorhus/following{/other_user}',
#     u'gists_url': u'https://api.github.com/users/sindresorhus/gists{/gist_id}',
#     u'gravatar_id': u'',
#     u'html_url': u'https://github.com/sindresorhus',
#     u'id': 170270,
#     u'login': u'sindresorhus',
#     u'organizations_url': u'https://api.github.com/users/sindresorhus/orgs',
#     u'received_events_url': u'https://api.github.com/users/sindresorhus/received_events',
#     u'repos_url': u'https://api.github.com/users/sindresorhus/repos',
#     u'site_admin': False,
#     u'starred_url': u'https://api.github.com/users/sindresorhus/starred{/owner}{/repo}',
#     u'subscriptions_url': u'https://api.github.com/users/sindresorhus/subscriptions',
#     u'type': u'User',
#     u'url': u'https://api.github.com/users/sindresorhus'}},
#   u'body': u'![image](https://cloud.githubusercontent.com/assets/5233399/16139367/019c6066-340c-11e6-82e8-2127a6dd0fbb.png)\r\n\r\nI made the decision to cache all users real names in `chrome.storage.local`, since I don\'t think it\'s super common for people to change their name. Let me know if anyone has any strong opinions here.\r\n\r\nSo far, I\'ve verified this works in the following places/scenarios:\r\n\r\n1. Comments on issues\r\n2. Comments on PRs\r\n3. "Outdated" comments in PRs (after clicking to expand)\r\n4. On partial page nav back/forward\r\n\r\n[Here is a good issue to use as a test case](https://github.com/isaacs/github/issues/9). Note the second refresh (after all names load) is much faster. Pretty happy that `chrome.storage` is async, or we\'d be having a baddd time.\r\n\r\nNote: I did this directly with native DOM APIs, but happy to switch the implementation over to Sprint if desired.',
#   u'closed_at': None,
#   u'comments_url': u'https://api.github.com/repos/sindresorhus/refined-github/issues/251/comments',
#   u'commits_url': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/251/commits',
#   u'created_at': u'2016-06-17T02:59:15Z',
#   u'diff_url': u'https://github.com/sindresorhus/refined-github/pull/251.diff',
#   u'head': {u'label': u'sindresorhus:real-names',
#    u'ref': u'real-names',
#    u'repo': {u'archive_url': u'https://api.github.com/repos/sindresorhus/refined-github/{archive_format}{/ref}',
#     u'assignees_url': u'https://api.github.com/repos/sindresorhus/refined-github/assignees{/user}',
#     u'blobs_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/blobs{/sha}',
#     u'branches_url': u'https://api.github.com/repos/sindresorhus/refined-github/branches{/branch}',
#     u'clone_url': u'https://github.com/sindresorhus/refined-github.git',
#     u'collaborators_url': u'https://api.github.com/repos/sindresorhus/refined-github/collaborators{/collaborator}',
#     u'comments_url': u'https://api.github.com/repos/sindresorhus/refined-github/comments{/number}',
#     u'commits_url': u'https://api.github.com/repos/sindresorhus/refined-github/commits{/sha}',
#     u'compare_url': u'https://api.github.com/repos/sindresorhus/refined-github/compare/{base}...{head}',
#     u'contents_url': u'https://api.github.com/repos/sindresorhus/refined-github/contents/{+path}',
#     u'contributors_url': u'https://api.github.com/repos/sindresorhus/refined-github/contributors',
#     u'created_at': u'2016-02-15T16:45:02Z',
#     u'default_branch': u'master',
#     u'deployments_url': u'https://api.github.com/repos/sindresorhus/refined-github/deployments',
#     u'description': u'Chrome extension that simplifies the GitHub interface and adds useful features',
#     u'downloads_url': u'https://api.github.com/repos/sindresorhus/refined-github/downloads',
#     u'events_url': u'https://api.github.com/repos/sindresorhus/refined-github/events',
#     u'fork': False,
#     u'forks': 60,
#     u'forks_count': 60,
#     u'forks_url': u'https://api.github.com/repos/sindresorhus/refined-github/forks',
#     u'full_name': u'sindresorhus/refined-github',
#     u'git_commits_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/commits{/sha}',
#     u'git_refs_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/refs{/sha}',
#     u'git_tags_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/tags{/sha}',
#     u'git_url': u'git://github.com/sindresorhus/refined-github.git',
#     u'has_downloads': True,
#     u'has_issues': True,
#     u'has_pages': False,
#     u'has_wiki': False,
#     u'homepage': u'https://chrome.google.com/webstore/detail/refined-github/hlepfoohegkhhmjieoechaddaejaokhf',
#     u'hooks_url': u'https://api.github.com/repos/sindresorhus/refined-github/hooks',
#     u'html_url': u'https://github.com/sindresorhus/refined-github',
#     u'id': 51769689,
#     u'issue_comment_url': u'https://api.github.com/repos/sindresorhus/refined-github/issues/comments{/number}',
#     u'issue_events_url': u'https://api.github.com/repos/sindresorhus/refined-github/issues/events{/number}',
#     u'issues_url': u'https://api.github.com/repos/sindresorhus/refined-github/issues{/number}',
#     u'keys_url': u'https://api.github.com/repos/sindresorhus/refined-github/keys{/key_id}',
#     u'labels_url': u'https://api.github.com/repos/sindresorhus/refined-github/labels{/name}',
#     u'language': u'JavaScript',
#     u'languages_url': u'https://api.github.com/repos/sindresorhus/refined-github/languages',
#     u'merges_url': u'https://api.github.com/repos/sindresorhus/refined-github/merges',
#     u'milestones_url': u'https://api.github.com/repos/sindresorhus/refined-github/milestones{/number}',
#     u'mirror_url': None,
#     u'name': u'refined-github',
#     u'notifications_url': u'https://api.github.com/repos/sindresorhus/refined-github/notifications{?since,all,participating}',
#     u'open_issues': 41,
#     u'open_issues_count': 41,
#     u'owner': {u'avatar_url': u'https://avatars.githubusercontent.com/u/170270?v=3',
#      u'events_url': u'https://api.github.com/users/sindresorhus/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/sindresorhus/followers',
#      u'following_url': u'https://api.github.com/users/sindresorhus/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/sindresorhus/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/sindresorhus',
#      u'id': 170270,
#      u'login': u'sindresorhus',
#      u'organizations_url': u'https://api.github.com/users/sindresorhus/orgs',
#      u'received_events_url': u'https://api.github.com/users/sindresorhus/received_events',
#      u'repos_url': u'https://api.github.com/users/sindresorhus/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/sindresorhus/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/sindresorhus/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/sindresorhus'},
#     u'private': False,
#     u'pulls_url': u'https://api.github.com/repos/sindresorhus/refined-github/pulls{/number}',
#     u'pushed_at': u'2016-06-17T23:45:09Z',
#     u'releases_url': u'https://api.github.com/repos/sindresorhus/refined-github/releases{/id}',
#     u'size': 1712,
#     u'ssh_url': u'git@github.com:sindresorhus/refined-github.git',
#     u'stargazers_count': 781,
#     u'stargazers_url': u'https://api.github.com/repos/sindresorhus/refined-github/stargazers',
#     u'statuses_url': u'https://api.github.com/repos/sindresorhus/refined-github/statuses/{sha}',
#     u'subscribers_url': u'https://api.github.com/repos/sindresorhus/refined-github/subscribers',
#     u'subscription_url': u'https://api.github.com/repos/sindresorhus/refined-github/subscription',
#     u'svn_url': u'https://github.com/sindresorhus/refined-github',
#     u'tags_url': u'https://api.github.com/repos/sindresorhus/refined-github/tags',
#     u'teams_url': u'https://api.github.com/repos/sindresorhus/refined-github/teams',
#     u'trees_url': u'https://api.github.com/repos/sindresorhus/refined-github/git/trees{/sha}',
#     u'updated_at': u'2016-06-17T21:29:24Z',
#     u'url': u'https://api.github.com/repos/sindresorhus/refined-github',
#     u'watchers': 781,
#     u'watchers_count': 781},
#    u'sha': u'a4af7b1c41e6850a1d0ae86e471840a3d28341b4',
#    u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/170270?v=3',
#     u'events_url': u'https://api.github.com/users/sindresorhus/events{/privacy}',
#     u'followers_url': u'https://api.github.com/users/sindresorhus/followers',
#     u'following_url': u'https://api.github.com/users/sindresorhus/following{/other_user}',
#     u'gists_url': u'https://api.github.com/users/sindresorhus/gists{/gist_id}',
#     u'gravatar_id': u'',
#     u'html_url': u'https://github.com/sindresorhus',
#     u'id': 170270,
#     u'login': u'sindresorhus',
#     u'organizations_url': u'https://api.github.com/users/sindresorhus/orgs',
#     u'received_events_url': u'https://api.github.com/users/sindresorhus/received_events',
#     u'repos_url': u'https://api.github.com/users/sindresorhus/repos',
#     u'site_admin': False,
#     u'starred_url': u'https://api.github.com/users/sindresorhus/starred{/owner}{/repo}',
#     u'subscriptions_url': u'https://api.github.com/users/sindresorhus/subscriptions',
#     u'type': u'User',
#     u'url': u'https://api.github.com/users/sindresorhus'}},
#   u'html_url': u'https://github.com/sindresorhus/refined-github/pull/251',
#   u'id': 74182621,
#   u'issue_url': u'https://api.github.com/repos/sindresorhus/refined-github/issues/251',
#   u'locked': False,
#   u'merge_commit_sha': u'b792b43c20942e0a5e5889f1263838e19a14abfc',
#   u'merged_at': None,
#   u'milestone': None,
#   u'number': 251,
#   u'patch_url': u'https://github.com/sindresorhus/refined-github/pull/251.patch',
#   u'review_comment_url': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/comments{/number}',
#   u'review_comments_url': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/251/comments',
#   u'state': u'open',
#   u'statuses_url': u'https://api.github.com/repos/sindresorhus/refined-github/statuses/a4af7b1c41e6850a1d0ae86e471840a3d28341b4',
#   u'title': u'Show real names next to usernames in comments. Closes #250',
#   u'updated_at': u'2016-06-17T23:58:49Z',
#   u'url': u'https://api.github.com/repos/sindresorhus/refined-github/pulls/251',
#   u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/5233399?v=3',
#    u'events_url': u'https://api.github.com/users/DrewML/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/DrewML/followers',
#    u'following_url': u'https://api.github.com/users/DrewML/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/DrewML/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/DrewML',
#    u'id': 5233399,
#    u'login': u'DrewML',
#    u'organizations_url': u'https://api.github.com/users/DrewML/orgs',
#    u'received_events_url': u'https://api.github.com/users/DrewML/received_events',
#    u'repos_url': u'https://api.github.com/users/DrewML/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/DrewML/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/DrewML/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/DrewML'}}}

# %% [markdown]
# ## Release Event
# Triggered when a release is published.
#
# `
# KEY      TYPE    DESCRIPTION
# action   string  The action that was performed. Currently, can only be "published".
# release  object  The release itself.
# `

# %%
# check the structure of Watch Event
ReleaseEvent = events[events['type'] == 'ReleaseEvent']

print ReleaseEvent.shape

ReleaseEvent.head()
# Out:
# (1320, 7)
#               type                                            payload  \
# 414   ReleaseEvent  {u'action': u'published', u'release': {u'body'...
# 415   ReleaseEvent  {u'action': u'published', u'release': {u'body'...
# 711   ReleaseEvent  {u'action': u'published', u'release': {u'body'...
# 893   ReleaseEvent  {u'action': u'published', u'release': {u'body'...
# 1043  ReleaseEvent  {u'action': u'published', u'release': {u'body'...
#
#        repo_id  user_id       login          created_at  archive_id
# 414   70534107  7341604     rcmalli 2016-10-15 09:41:26  4715111891
# 415   48933503  1820165  afollestad 2016-02-29 20:12:02  3703380867
# 711   54994103  5382443   FezVrasta 2016-03-29 21:37:19  3821753509
# 893   53632140  5513065    zyedidia 2016-12-13 00:02:52  5009951237
# 1043  53632140  5513065    zyedidia 2016-11-23 00:02:28  4910890860

# %%
RE_payload = pd.DataFrame(ReleaseEvent['payload'].tolist())

# %%
RE_payload_release = pd.DataFrame(RE_payload['release'].tolist())

# %%
pd.DataFrame(RE_payload_release['assets'].tolist())
# Out:
#                                                      0   \
# 0     {u'uploader': {u'following_url': u'https://api...
# 1     {u'uploader': {u'following_url': u'https://api...
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13    {u'uploader': {u'following_url': u'https://api...
# 14                                                 None
# 15                                                 None
# 16    {u'uploader': {u'following_url': u'https://api...
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21    {u'uploader': {u'following_url': u'https://api...
# 22    {u'uploader': {u'following_url': u'https://api...
# 23                                                 None
# 24    {u'uploader': {u'following_url': u'https://api...
# 25    {u'uploader': {u'following_url': u'https://api...
# 26    {u'uploader': {u'following_url': u'https://api...
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 1290                                               None
# 1291                                               None
# 1292                                               None
# 1293                                               None
# 1294                                               None
# 1295                                               None
# 1296                                               None
# 1297  {u'uploader': {u'following_url': u'https://api...
# 1298                                               None
# 1299                                               None
# 1300                                               None
# 1301                                               None
# 1302                                               None
# 1303                                               None
# 1304                                               None
# 1305                                               None
# 1306                                               None
# 1307                                               None
# 1308                                               None
# 1309                                               None
# 1310                                               None
# 1311                                               None
# 1312                                               None
# 1313                                               None
# 1314                                               None
# 1315                                               None
# 1316                                               None
# 1317                                               None
# 1318                                               None
# 1319                                               None
#
#                                                      1   \
# 0     {u'uploader': {u'following_url': u'https://api...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13    {u'uploader': {u'following_url': u'https://api...
# 14                                                 None
# 15                                                 None
# 16    {u'uploader': {u'following_url': u'https://api...
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 1290                                               None
# 1291                                               None
# 1292                                               None
# 1293                                               None
# 1294                                               None
# 1295                                               None
# 1296                                               None
# 1297                                               None
# 1298                                               None
# 1299                                               None
# 1300                                               None
# 1301                                               None
# 1302                                               None
# 1303                                               None
# 1304                                               None
# 1305                                               None
# 1306                                               None
# 1307                                               None
# 1308                                               None
# 1309                                               None
# 1310                                               None
# 1311                                               None
# 1312                                               None
# 1313                                               None
# 1314                                               None
# 1315                                               None
# 1316                                               None
# 1317                                               None
# 1318                                               None
# 1319                                               None
#
#                                                      2   \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13    {u'uploader': {u'following_url': u'https://api...
# 14                                                 None
# 15                                                 None
# 16    {u'uploader': {u'following_url': u'https://api...
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 1290                                               None
# 1291                                               None
# 1292                                               None
# 1293                                               None
# 1294                                               None
# 1295                                               None
# 1296                                               None
# 1297                                               None
# 1298                                               None
# 1299                                               None
# 1300                                               None
# 1301                                               None
# 1302                                               None
# 1303                                               None
# 1304                                               None
# 1305                                               None
# 1306                                               None
# 1307                                               None
# 1308                                               None
# 1309                                               None
# 1310                                               None
# 1311                                               None
# 1312                                               None
# 1313                                               None
# 1314                                               None
# 1315                                               None
# 1316                                               None
# 1317                                               None
# 1318                                               None
# 1319                                               None
#
#                                                      3   \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13    {u'uploader': {u'following_url': u'https://api...
# 14                                                 None
# 15                                                 None
# 16    {u'uploader': {u'following_url': u'https://api...
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 1290                                               None
# 1291                                               None
# 1292                                               None
# 1293                                               None
# 1294                                               None
# 1295                                               None
# 1296                                               None
# 1297                                               None
# 1298                                               None
# 1299                                               None
# 1300                                               None
# 1301                                               None
# 1302                                               None
# 1303                                               None
# 1304                                               None
# 1305                                               None
# 1306                                               None
# 1307                                               None
# 1308                                               None
# 1309                                               None
# 1310                                               None
# 1311                                               None
# 1312                                               None
# 1313                                               None
# 1314                                               None
# 1315                                               None
# 1316                                               None
# 1317                                               None
# 1318                                               None
# 1319                                               None
#
#                                                      4   \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13    {u'uploader': {u'following_url': u'https://api...
# 14                                                 None
# 15                                                 None
# 16    {u'uploader': {u'following_url': u'https://api...
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 1290                                               None
# 1291                                               None
# 1292                                               None
# 1293                                               None
# 1294                                               None
# 1295                                               None
# 1296                                               None
# 1297                                               None
# 1298                                               None
# 1299                                               None
# 1300                                               None
# 1301                                               None
# 1302                                               None
# 1303                                               None
# 1304                                               None
# 1305                                               None
# 1306                                               None
# 1307                                               None
# 1308                                               None
# 1309                                               None
# 1310                                               None
# 1311                                               None
# 1312                                               None
# 1313                                               None
# 1314                                               None
# 1315                                               None
# 1316                                               None
# 1317                                               None
# 1318                                               None
# 1319                                               None
#
#                                                      5     6     7     8   \
# 0                                                  None  None  None  None
# 1                                                  None  None  None  None
# 2                                                  None  None  None  None
# 3                                                  None  None  None  None
# 4                                                  None  None  None  None
# 5                                                  None  None  None  None
# 6                                                  None  None  None  None
# 7                                                  None  None  None  None
# 8                                                  None  None  None  None
# 9                                                  None  None  None  None
# 10                                                 None  None  None  None
# 11                                                 None  None  None  None
# 12                                                 None  None  None  None
# 13    {u'uploader': {u'following_url': u'https://api...  None  None  None
# 14                                                 None  None  None  None
# 15                                                 None  None  None  None
# 16                                                 None  None  None  None
# 17                                                 None  None  None  None
# 18                                                 None  None  None  None
# 19                                                 None  None  None  None
# 20                                                 None  None  None  None
# 21                                                 None  None  None  None
# 22                                                 None  None  None  None
# 23                                                 None  None  None  None
# 24                                                 None  None  None  None
# 25                                                 None  None  None  None
# 26                                                 None  None  None  None
# 27                                                 None  None  None  None
# 28                                                 None  None  None  None
# 29                                                 None  None  None  None
# ...                                                 ...   ...   ...   ...
# 1290                                               None  None  None  None
# 1291                                               None  None  None  None
# 1292                                               None  None  None  None
# 1293                                               None  None  None  None
# 1294                                               None  None  None  None
# 1295                                               None  None  None  None
# 1296                                               None  None  None  None
# 1297                                               None  None  None  None
# 1298                                               None  None  None  None
# 1299                                               None  None  None  None
# 1300                                               None  None  None  None
# 1301                                               None  None  None  None
# 1302                                               None  None  None  None
# 1303                                               None  None  None  None
# 1304                                               None  None  None  None
# 1305                                               None  None  None  None
# 1306                                               None  None  None  None
# 1307                                               None  None  None  None
# 1308                                               None  None  None  None
# 1309                                               None  None  None  None
# 1310                                               None  None  None  None
# 1311                                               None  None  None  None
# 1312                                               None  None  None  None
# 1313                                               None  None  None  None
# 1314                                               None  None  None  None
# 1315                                               None  None  None  None
# 1316                                               None  None  None  None
# 1317                                               None  None  None  None
# 1318                                               None  None  None  None
# 1319                                               None  None  None  None
#
#         9     10    11
# 0     None  None  None
# 1     None  None  None
# 2     None  None  None
# 3     None  None  None
# 4     None  None  None
# 5     None  None  None
# 6     None  None  None
# 7     None  None  None
# 8     None  None  None
# 9     None  None  None
# 10    None  None  None
# 11    None  None  None
# 12    None  None  None
# 13    None  None  None
# 14    None  None  None
# 15    None  None  None
# 16    None  None  None
# 17    None  None  None
# 18    None  None  None
# 19    None  None  None
# 20    None  None  None
# 21    None  None  None
# 22    None  None  None
# 23    None  None  None
# 24    None  None  None
# 25    None  None  None
# 26    None  None  None
# 27    None  None  None
# 28    None  None  None
# 29    None  None  None
# ...    ...   ...   ...
# 1290  None  None  None
# 1291  None  None  None
# 1292  None  None  None
# 1293  None  None  None
# 1294  None  None  None
# 1295  None  None  None
# 1296  None  None  None
# 1297  None  None  None
# 1298  None  None  None
# 1299  None  None  None
# 1300  None  None  None
# 1301  None  None  None
# 1302  None  None  None
# 1303  None  None  None
# 1304  None  None  None
# 1305  None  None  None
# 1306  None  None  None
# 1307  None  None  None
# 1308  None  None  None
# 1309  None  None  None
# 1310  None  None  None
# 1311  None  None  None
# 1312  None  None  None
# 1313  None  None  None
# 1314  None  None  None
# 1315  None  None  None
# 1316  None  None  None
# 1317  None  None  None
# 1318  None  None  None
# 1319  None  None  None
#
# [1320 rows x 12 columns]

# %%
RE_payload_release['draft'].unique()
# Out:
# array([False], dtype=object)

# %%
RL = []

for index, row in ReleaseEvent.iterrows():
    
    payload = row['payload']
    release = payload['release']
    
    RL.append({'repo_id': row['repo_id'], 'user_id': row['user_id'], 
               'user_login': row['login'], 'date_published': pd.to_datetime(row['created_at']),
               'archive_id': row['archive_id'], 
               'description': release['body'], 'date_created': pd.to_datetime(release['created_at']),
               'url': release['html_url'], 'release_id': pd.to_numeric(release['id']), 'name': release['name'],
               'prerelease': release['prerelease'], 'tag_name': release['tag_name'],
               'target_commitish': release['target_commitish']})

# %%
release_table = pd.DataFrame(RL)

release_table.head()
# Out:
#    archive_id        date_created      date_published  \
# 0  4715111891 2016-10-15 09:33:56 2016-10-15 09:41:26
# 1  3703380867 2016-02-29 20:06:02 2016-02-29 20:12:02
# 2  3821753509 2016-03-29 21:24:40 2016-03-29 21:37:19
# 3  5009951237 2016-12-11 21:43:07 2016-12-13 00:02:52
# 4  4910890860 2016-11-20 16:07:04 2016-11-23 00:02:28
#
#                                          description           name  \
# 0                                                              v0.4
# 1  1. Some internal library updates, including Ap...          1.3.0
# 2  This is the first stable release of Near.js in...        Near.js
# 3               Autogenerated nightly build of micro  Nightly build
# 4               Autogenerated nightly build of micro  Nightly build
#
#   prerelease  release_id   repo_id tag_name target_commitish  \
# 0      False     4397054  70534107     v0.4       squeezenet
# 1      False     2713152  48933503    1.3.0           master
# 2      False     2910797  54994103   v0.1.0           master
# 3       True     4900653  53632140  nightly           master
# 4       True     4736225  53632140  nightly           master
#
#                                                  url  user_id  user_login
# 0  https://github.com/rcmalli/deep-learning-model...  7341604     rcmalli
# 1  https://github.com/afollestad/polar-dashboard/...  1820165  afollestad
# 2  https://github.com/FezVrasta/popper.js/release...  5382443   FezVrasta
# 3  https://github.com/zyedidia/micro/releases/tag...  5513065    zyedidia
# 4  https://github.com/zyedidia/micro/releases/tag...  5513065    zyedidia

# %%
# drop duplicates across ALL columns
release_table = release_table.drop_duplicates()

release_table.shape
# Out:
# (1318, 13)

# %%
create_release_table = '''
CREATE TABLE release_events (
    release_id       NUMERIC      NOT NULL,
    repo_id          NUMERIC      NOT NULL,
    date_created     TEXT         NOT NULL,
    date_published   TEXT         NOT NULL,
    name             VARCHAR (50),
    description      TEXT,
    prerelease       INT          NOT NULL,
    target_commitish VARCHAR (50) NOT NULL,
    tag_name         VARCHAR (50) NOT NULL,
    url              TEXT         NOT NULL,
    user_id          NUMERIC      NOT NULL,
    user_login       VARCHAR (40) NOT NULL,
    archive_id       NUMERIC      NOT NULL,
    PRIMARY KEY (
        release_id,
        repo_id,
        date_created,
        date_published
    )
)
WITHOUT ROWID;
'''

# %%
c.execute(create_release_table)
con.commit()

# %%
release_table.to_sql(name='release_events', con=con, if_exists='append', index=False)

# %% [markdown]
# ## Commit Comment Event
# Triggered when a commit comment is created.
#
# `
# KEY      TYPE    DESCRIPTION
# comment  object  The comment itself.
# `

# %%
events[events['type'] == 'CommitCommentEvent'].head()
# Out:
#                     type                                            payload  \
# 156   CommitCommentEvent  {u'comment': {u'commit_id': u'6eeebef7153392f7...
# 921   CommitCommentEvent  {u'comment': {u'commit_id': u'ca1dfd904d9a7a5c...
# 1622  CommitCommentEvent  {u'comment': {u'commit_id': u'7460f8c8019b4721...
# 2307  CommitCommentEvent  {u'comment': {u'commit_id': u'52201980c02160e1...
# 2452  CommitCommentEvent  {u'comment': {u'commit_id': u'00a626ec9a21c0d4...
#
#        repo_id   user_id           login               created_at  archive_id
# 156   51905436      4699  demetriusnunes  2016-10-17 18:50:26 UTC  4722793643
# 921   61412022   3254314   mathieudutour  2016-07-17 23:19:46 UTC  4289198735
# 1622  54027312   2439146    patchthecode  2016-12-24 20:17:31 UTC  5068635588
# 2307  63730796  20220872  harshmasters07  2016-08-05 12:25:31 UTC  4377838170
# 2452  51905436   4154003        dherault  2016-03-15 22:53:15 UTC  3767542773

# %%
events['payload'][events['type'] == 'CommitCommentEvent'].iloc[0]
# Out:
# {u'comment': {u'body': u'Now `this` is undefined, so `this.serverlessLog` throws.',
#   u'commit_id': u'6eeebef7153392f714e018052f6a76c8b80bab48',
#   u'created_at': u'2016-10-17T18:50:26Z',
#   u'html_url': u'https://github.com/dherault/serverless-offline/commit/6eeebef7153392f714e018052f6a76c8b80bab48#commitcomment-19456791',
#   u'id': 19456791,
#   u'line': 326,
#   u'path': u'src/index.js',
#   u'position': 67,
#   u'updated_at': u'2016-10-17T18:50:26Z',
#   u'url': u'https://api.github.com/repos/dherault/serverless-offline/comments/19456791',
#   u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/4699?v=3',
#    u'events_url': u'https://api.github.com/users/demetriusnunes/events{/privacy}',
#    u'followers_url': u'https://api.github.com/users/demetriusnunes/followers',
#    u'following_url': u'https://api.github.com/users/demetriusnunes/following{/other_user}',
#    u'gists_url': u'https://api.github.com/users/demetriusnunes/gists{/gist_id}',
#    u'gravatar_id': u'',
#    u'html_url': u'https://github.com/demetriusnunes',
#    u'id': 4699,
#    u'login': u'demetriusnunes',
#    u'organizations_url': u'https://api.github.com/users/demetriusnunes/orgs',
#    u'received_events_url': u'https://api.github.com/users/demetriusnunes/received_events',
#    u'repos_url': u'https://api.github.com/users/demetriusnunes/repos',
#    u'site_admin': False,
#    u'starred_url': u'https://api.github.com/users/demetriusnunes/starred{/owner}{/repo}',
#    u'subscriptions_url': u'https://api.github.com/users/demetriusnunes/subscriptions',
#    u'type': u'User',
#    u'url': u'https://api.github.com/users/demetriusnunes'}}}

# %% [markdown]
# ## Member Event
# Triggered when a user is added or removed as a collaborator to a repository, or has their permissions changed.
#
# `
# member                        object  The user that was added.
# action                        string  The action that was performed. Can be one of "added", "deleted", or "edited"
# changes                       object  The changes to the collaborator permissions if the action was "edited"
# changes[old_permission][from] string  The previous permissions of the collaborator if the action was "edited"
# `

# %%
MemberEvent = events[events['type'] == 'MemberEvent']

# %%
MemberEvent.head(n=1)
# Out:
#              type                                            payload  \
# 1218  MemberEvent  {u'member': {u'following_url': u'https://api.g...
#
#        repo_id   user_id    login          created_at  archive_id
# 1218  59815426  11867815  majia67 2016-08-05 14:45:16  4378518804

# %%
MemberEvent['payload'].iloc[0]
# Out:
# {u'action': u'added',
#  u'member': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8280291?v=3',
#   u'events_url': u'https://api.github.com/users/easyworld/events{/privacy}',
#   u'followers_url': u'https://api.github.com/users/easyworld/followers',
#   u'following_url': u'https://api.github.com/users/easyworld/following{/other_user}',
#   u'gists_url': u'https://api.github.com/users/easyworld/gists{/gist_id}',
#   u'gravatar_id': u'',
#   u'html_url': u'https://github.com/easyworld',
#   u'id': 8280291,
#   u'login': u'easyworld',
#   u'organizations_url': u'https://api.github.com/users/easyworld/orgs',
#   u'received_events_url': u'https://api.github.com/users/easyworld/received_events',
#   u'repos_url': u'https://api.github.com/users/easyworld/repos',
#   u'site_admin': False,
#   u'starred_url': u'https://api.github.com/users/easyworld/starred{/owner}{/repo}',
#   u'subscriptions_url': u'https://api.github.com/users/easyworld/subscriptions',
#   u'type': u'User',
#   u'url': u'https://api.github.com/users/easyworld'}}

# %%
# there are only users added
MemberEvent_payload = pd.DataFrame(MemberEvent['payload'].tolist())

MemberEvent_payload['action'].unique()
# Out:
# array([u'added'], dtype=object)

# %%
ML = []

for index, row in MemberEvent.iterrows():
    
    payload = row['payload']
    member = payload['member']

    ML.append({'repo_id': row['repo_id'], 'by_user_id': row['user_id'],
               'by_user_login': row['login'], 'action_date': row['created_at'],
               'archive_id': row['archive_id'], 'action':payload['action'], 
               'at_user_id': pd.to_numeric(member['id']), 'at_user_login': member['login']})

# %%
member_table = pd.DataFrame(ML)

# %%
member_table.head()
# Out:
#   action         action_date  archive_id  at_user_id at_user_login  \
# 0  added 2016-08-05 14:45:16  4378518804     8280291     easyworld
# 1  added 2016-08-29 00:27:01  4481744866     1712363      keyphact
# 2  added 2016-11-27 06:38:03  4928235573    11958359    AkiraLaine
# 3  added 2016-04-05 10:05:28  3847383026    18283204     andynoack
# 4  added 2016-09-02 19:23:32  4510275804    20820195     wagamamaz
#
#    by_user_id  by_user_login   repo_id
# 0    11867815        majia67  59815426
# 1     4643257      AeonLucid  63506379
# 2     8327811  SimulatedGREG  58616946
# 3    18219846         jopohl  55258005
# 4    10713581      zsdonghao  60626727

# %%
create_members_table = '''
CREATE TABLE member_events (
    repo_id       NUMERIC      NOT NULL,
    action_date   TEXT         NOT NULL,
    [action]      VARCAHR (15) NOT NULL,
    at_user_id    NUMERIC      NOT NULL,
    at_user_login VARCHAR (40) NOT NULL,
    by_user_id    NUMERIC      NOT NULL,
    by_user_login VARCHAR (40) NOT NULL,
    archive_id    NUMERIC      NOT NULL,
    PRIMARY KEY (
        repo_id,
        action_date,
        at_user_id
    )
)
WITHOUT ROWID;
'''

# %%
c.execute(create_members_table)
con.commit()

# %%
member_table.to_sql(name='member_events', con=con, if_exists='append', index=False)

# %% [markdown]
# ## Public Event
# Triggered when a private repository is open sourced.

# %%
events[events['type'] == 'PublicEvent'].head()
# Out:
#               type payload   repo_id  user_id          login  \
# 2915   PublicEvent      {}  67749622  2577440         tqchen
# 14965  PublicEvent      {}  61355800  8341653   daijifeng001
# 24271  PublicEvent      {}  57929326  1612723    emeryberger
# 33191  PublicEvent      {}  64519183  6261322       logaretm
# 34361  PublicEvent      {}  54168759  1480321  SergioBenitez
#
#                created_at  archive_id
# 2915  2016-09-30 04:17:37  4641374648
# 14965 2016-06-21 07:33:32  4172657198
# 24271 2016-05-16 00:21:35  4017077526
# 33191 2016-08-15 03:35:31  4417258560
# 34361 2016-12-23 15:38:42  5066128048

# %%
public_table = events[['repo_id', 'user_id', 'login', 'created_at', 'archive_id']][events['type'] == 'PublicEvent']

# %%
public_table = public_table.rename(columns={'login':'user_login', 'created_at': 'date_open_sourced'})

# %%
create_public_table = '''
CREATE TABLE public_events (
    repo_id           NUMERIC      NOT NULL,
    date_open_sourced TEXT         NOT NULL,
    user_id           NUMERIC      NOT NULL,
    user_login        VARCHAR (40) NOT NULL,
    archive_id        NUMERIC      NOT NULL,
    PRIMARY KEY (
        repo_id,
        user_id,
        date_open_sourced
    )
)
WITHOUT ROWID;
'''

# %%
c.execute(create_public_table)
con.commit()

# %%
public_table.to_sql(name='public_events', con=con, if_exists='append', index=False)

# %% [markdown]
# ## Resources
# - https://apple.stackexchange.com/questions/80611/merging-multiple-csv-files-without-merging-the-header
# - https://stackoverflow.com/questions/16890582/unixmerge-multiple-csv-files-with-same-header-by-keeping-the-header-of-the-firs
# - https://stackoverflow.com/questions/21129020/how-to-fix-unicodedecodeerror-ascii-codec-cant-decode-byte
# - https://stackoverflow.com/questions/988228/convert-a-string-representation-of-a-dictionary-to-a-dictionary
# - https://stackoverflow.com/questions/29712962/how-can-i-convert-string-to-dict-or-list
# - https://stackoverflow.com/questions/36606930/delete-an-element-in-a-json-object
# - https://stackoverflow.com/questions/21745213/changed-github-password-no-longer-able-to-push-back-to-the-remote
# - https://stackoverflow.com/questions/14661701/how-to-drop-a-list-of-rows-from-pandas-dataframe
# - https://stackoverflow.com/questions/25494182/print-not-showing-in-ipython-notebook-python
